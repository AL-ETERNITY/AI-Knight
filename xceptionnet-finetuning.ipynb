# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import numpy as np
import pandas as pd
import logging
import warnings as warnings
import random
import pickle

import tensorflow as tf
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.utils import Sequence
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    TensorBoard,
    ModelCheckpoint,
    Callback
)

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
# Configuration and Setup

# Suppress warnings
warnings.filterwarnings('ignore')

# Configure logging
logging.basicConfig(
    level=logging.DEBUG,  # Set to DEBUG level for detailed logging
    format='%(asctime)s [%(levelname)s] %(message)s',
    handlers=[
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Set seeds for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# Enable memory growth for GPUs
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"Enabled memory growth for {len(gpus)} GPU(s).")
    except RuntimeError as e:
        print(f"Error setting memory growth: {e}")
# Out:
# Enabled memory growth for 2 GPU(s).

# %%
test_dir = '/kaggle/input/ai-knight/dataset/test'
train_dir = '/kaggle/input/ai-knight/dataset/train'

IMG_SIZE = (224,224)
BATCH_SIZE = 32

# %%
# Data Loading and Preprocessing

# Load data
# Load training data
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,            # Reserve 20% of data for validation
    subset="training",               # Load the training subset
    seed=42,                         # Set seed for reproducibility
    labels="inferred",               # Automatically assigns labels
    label_mode="int",                # Outputs integer labels
    image_size=IMG_SIZE,             # Resize images to target size
    batch_size=BATCH_SIZE,           # Batch size
    shuffle=True                     # Shuffle the data
)

#load val data '
val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,            # Reserve 20% of data for validation
    subset="validation",             # Load the validation subset
    seed=42,                         # Set seed for reproducibility
    labels="inferred",               # Automatically assigns labels
    label_mode="int",                # Outputs integer labels
    image_size=IMG_SIZE,             # Resize images to target size
    batch_size=BATCH_SIZE,           # Batch size
    shuffle=True                     # Shuffle the data
)
#fake - 0, real - 1
# Out:
# Found 100000 files belonging to 2 classes.
# Using 80000 files for training.
# Found 100000 files belonging to 2 classes.
# Using 20000 files for validation.

# %%
print(f"Training batches: {len(train_dataset)}")
print(f"Validation batches: {len(val_dataset)}")
print(train_dataset.class_names)  # Output: ['fake', 'real']
# Out:
# Training batches: 2500
# Validation batches: 625
# ['fake', 'real']

# %%
#build the model 

input_shape = IMG_SIZE + (3,)
base_model = Xception(include_top=False, weights='imagenet', input_shape=input_shape)
base_model.trainable = False  # Freeze the base model
# print("Loaded EfficientNetB3 base model with ImageNet weights.")

# Add custom layers on top of the base model
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

# Add the output layer
output = Dense(1, activation='sigmoid')(x)  # Single unit with sigmoid activation for binary classification

# Define the complete model
model = Model(inputs=base_model.input, outputs=output)
print("Model architecture created.")

# Print model summary
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model architecture created.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1 (Conv2D)     │ (None, 111, 111, 32)   │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1_bn           │ (None, 111, 111, 32)   │            128 │ block1_conv1[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1_act          │ (None, 111, 111, 32)   │              0 │ block1_conv1_bn[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2 (Conv2D)     │ (None, 109, 109, 64)   │         18,432 │ block1_conv1_act[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2_bn           │ (None, 109, 109, 64)   │            256 │ block1_conv2[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2_act          │ (None, 109, 109, 64)   │              0 │ block1_conv2_bn[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv1           │ (None, 109, 109, 128)  │          8,768 │ block1_conv2_act[0][0] │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv1_bn        │ (None, 109, 109, 128)  │            512 │ block2_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv2_act       │ (None, 109, 109, 128)  │              0 │ block2_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv2           │ (None, 109, 109, 128)  │         17,536 │ block2_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv2_bn        │ (None, 109, 109, 128)  │            512 │ block2_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 55, 55, 128)    │          8,192 │ block1_conv2_act[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_pool               │ (None, 55, 55, 128)    │              0 │ block2_sepconv2_bn[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 55, 55, 128)    │            512 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 55, 55, 128)    │              0 │ block2_pool[0][0],     │
# │                           │                        │                │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv1_act       │ (None, 55, 55, 128)    │              0 │ add[0][0]              │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv1           │ (None, 55, 55, 256)    │         33,920 │ block3_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv1_bn        │ (None, 55, 55, 256)    │          1,024 │ block3_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv2_act       │ (None, 55, 55, 256)    │              0 │ block3_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv2           │ (None, 55, 55, 256)    │         67,840 │ block3_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv2_bn        │ (None, 55, 55, 256)    │          1,024 │ block3_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 28, 28, 256)    │         32,768 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_pool               │ (None, 28, 28, 256)    │              0 │ block3_sepconv2_bn[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 28, 28, 256)    │          1,024 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 28, 28, 256)    │              0 │ block3_pool[0][0],     │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv1_act       │ (None, 28, 28, 256)    │              0 │ add_1[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv1           │ (None, 28, 28, 728)    │        188,672 │ block4_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv1_bn        │ (None, 28, 28, 728)    │          2,912 │ block4_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv2_act       │ (None, 28, 28, 728)    │              0 │ block4_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv2           │ (None, 28, 28, 728)    │        536,536 │ block4_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv2_bn        │ (None, 28, 28, 728)    │          2,912 │ block4_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 14, 14, 728)    │        186,368 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_pool               │ (None, 14, 14, 728)    │              0 │ block4_sepconv2_bn[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 14, 14, 728)    │          2,912 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 14, 14, 728)    │              0 │ block4_pool[0][0],     │
# │                           │                        │                │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block5_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block5_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block5_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block5_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block5_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block5_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block5_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block5_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 14, 14, 728)    │              0 │ block5_sepconv3_bn[0]… │
# │                           │                        │                │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_3[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block6_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block6_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block6_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block6_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block6_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block6_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block6_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block6_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 14, 14, 728)    │              0 │ block6_sepconv3_bn[0]… │
# │                           │                        │                │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block7_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block7_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block7_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block7_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block7_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block7_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block7_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block7_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 14, 14, 728)    │              0 │ block7_sepconv3_bn[0]… │
# │                           │                        │                │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_5[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block8_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block8_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block8_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block8_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block8_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block8_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block8_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block8_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 14, 14, 728)    │              0 │ block8_sepconv3_bn[0]… │
# │                           │                        │                │ add_5[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_6[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block9_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block9_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block9_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block9_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block9_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block9_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block9_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block9_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 14, 14, 728)    │              0 │ block9_sepconv3_bn[0]… │
# │                           │                        │                │ add_6[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_7[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block10_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block10_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block10_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv2          │ (None, 14, 14, 728)    │        536,536 │ block10_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv2_bn       │ (None, 14, 14, 728)    │          2,912 │ block10_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv3_act      │ (None, 14, 14, 728)    │              0 │ block10_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv3          │ (None, 14, 14, 728)    │        536,536 │ block10_sepconv3_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv3_bn       │ (None, 14, 14, 728)    │          2,912 │ block10_sepconv3[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 14, 14, 728)    │              0 │ block10_sepconv3_bn[0… │
# │                           │                        │                │ add_7[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_8[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block11_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block11_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block11_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv2          │ (None, 14, 14, 728)    │        536,536 │ block11_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv2_bn       │ (None, 14, 14, 728)    │          2,912 │ block11_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv3_act      │ (None, 14, 14, 728)    │              0 │ block11_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv3          │ (None, 14, 14, 728)    │        536,536 │ block11_sepconv3_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv3_bn       │ (None, 14, 14, 728)    │          2,912 │ block11_sepconv3[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 14, 14, 728)    │              0 │ block11_sepconv3_bn[0… │
# │                           │                        │                │ add_8[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_9[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block12_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block12_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block12_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv2          │ (None, 14, 14, 728)    │        536,536 │ block12_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv2_bn       │ (None, 14, 14, 728)    │          2,912 │ block12_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv3_act      │ (None, 14, 14, 728)    │              0 │ block12_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv3          │ (None, 14, 14, 728)    │        536,536 │ block12_sepconv3_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv3_bn       │ (None, 14, 14, 728)    │          2,912 │ block12_sepconv3[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 14, 14, 728)    │              0 │ block12_sepconv3_bn[0… │
# │                           │                        │                │ add_9[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_10[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block13_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block13_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block13_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv2          │ (None, 14, 14, 1024)   │        752,024 │ block13_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv2_bn       │ (None, 14, 14, 1024)   │          4,096 │ block13_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 7, 7, 1024)     │        745,472 │ add_10[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_pool              │ (None, 7, 7, 1024)     │              0 │ block13_sepconv2_bn[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 7, 7, 1024)     │          4,096 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 7, 7, 1024)     │              0 │ block13_pool[0][0],    │
# │                           │                        │                │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv1          │ (None, 7, 7, 1536)     │      1,582,080 │ add_11[0][0]           │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv1_bn       │ (None, 7, 7, 1536)     │          6,144 │ block14_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv1_act      │ (None, 7, 7, 1536)     │              0 │ block14_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv2          │ (None, 7, 7, 2048)     │      3,159,552 │ block14_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv2_bn       │ (None, 7, 7, 2048)     │          8,192 │ block14_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv2_act      │ (None, 7, 7, 2048)     │              0 │ block14_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 2048)           │              0 │ block14_sepconv2_act[… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 2048)           │          8,192 │ global_average_poolin… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 2048)           │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1)              │          2,049 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 20,871,721 (79.62 MB)
#  Trainable params: 6,145 (24.00 KB)
#  Non-trainable params: 20,865,576 (79.60 MB)

# %%
# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),  # Use Adam optimizer with a learning rate of 1e-3 
    loss='binary_crossentropy',                              # Binary cross-entropy loss for binary classification
    metrics=['accuracy']                                     # Track accuracy during training
)

# %%
# Define Callbacks

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',                # Monitor validation loss
    patience=5,                        # Stop training if no improvement for 5 epochs
    restore_best_weights=True,         # Restore model weights from the epoch with the best value
    verbose=1                          # Print logs when stopping
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',                # Monitor validation loss
    factor=0.5,                        # Reduce learning rate by half
    patience=2,                        # Wait for 2 epochs before reducing
    verbose=1                          # Print logs about learning rate changes
)

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_model.keras',       # Filepath to save the best model
    monitor='val_loss',                # Monitor validation loss
    save_best_only=True,               # Save only if the model improves
    verbose=1                          # Print logs when saving
)

tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir='./logs',                  # Directory to save logs
    histogram_freq=1                   # Frequency (in epochs) to compute histograms
)

class BatchLoggingCallback(tf.keras.callbacks.Callback): #can be removed 
    def __init__(self, log_every=10):
        super(BatchLoggingCallback, self).__init__()
        self.log_every = log_every

    def on_train_batch_end(self, batch, logs=None):
        if (batch + 1) % self.log_every == 0:
            log_message = f"Batch {batch + 1}: " + ", ".join([f"{k}={v:.4f}" for k, v in logs.items()])
            print(log_message)

batch_logging = BatchLoggingCallback(log_every=10)



callbacks = [early_stop, reduce_lr, checkpoint, tensorboard_callback, batch_logging]

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=10,                      # Set the maximum number of epochs
    callbacks=callbacks,             # Add callbacks to monitor and enhance training
    verbose=1
    #also give step per epoch
)
# Out:
# Epoch 1/10
#    9/2500 ━━━━━━━━━━━━━━━━━━━━ 4:29 108ms/step - accuracy: 0.4491 - loss: 0.9094Batch 10: accuracy=0.4656, loss=0.8857
#   19/2500 ━━━━━━━━━━━━━━━━━━━━ 4:20 105ms/step - accuracy: 0.4719 - loss: 0.8844Batch 20: accuracy=0.5203, loss=0.8256
#   29/2500 ━━━━━━━━━━━━━━━━━━━━ 4:17 104ms/step - accuracy: 0.4924 - loss: 0.8589Batch 30: accuracy=0.5490, loss=0.7820
#   39/2500 ━━━━━━━━━━━━━━━━━━━━ 4:15 104ms/step - accuracy: 0.5072 - loss: 0.8404Batch 40: accuracy=0.5578, loss=0.7839
#   49/2500 ━━━━━━━━━━━━━━━━━━━━ 4:14 104ms/step - accuracy: 0.5194 - loss: 0.8278Batch 50: accuracy=0.5769, loss=0.7768
#   59/2500 ━━━━━━━━━━━━━━━━━━━━ 4:13 104ms/step - accuracy: 0.5295 - loss: 0.8186Batch 60: accuracy=0.5807, loss=0.7699
#   69/2500 ━━━━━━━━━━━━━━━━━━━━ 4:11 104ms/step - accuracy: 0.5373 - loss: 0.8112Batch 70: accuracy=0.5857, loss=0.7620
#   79/2500 ━━━━━━━━━━━━━━━━━━━━ 4:10 104ms/step - accuracy: 0.5440 - loss: 0.8043Batch 80: accuracy=0.5965, loss=0.7491
#   89/2500 ━━━━━━━━━━━━━━━━━━━━ 4:09 104ms/step - accuracy: 0.5503 - loss: 0.7977Batch 90: accuracy=0.6045, loss=0.7413
#   99/2500 ━━━━━━━━━━━━━━━━━━━━ 4:08 104ms/step - accuracy: 0.5561 - loss: 0.7916Batch 100: accuracy=0.6109, loss=0.7328
#  109/2500 ━━━━━━━━━━━━━━━━━━━━ 4:07 104ms/step - accuracy: 0.5612 - loss: 0.7863Batch 110: accuracy=0.6119, loss=0.7356
#  119/2500 ━━━━━━━━━━━━━━━━━━━━ 4:06 104ms/step - accuracy: 0.5656 - loss: 0.7819Batch 120: accuracy=0.6159, loss=0.7315
#  129/2500 ━━━━━━━━━━━━━━━━━━━━ 4:06 104ms/step - accuracy: 0.5697 - loss: 0.7777Batch 130: accuracy=0.6216, loss=0.7229
#  139/2500 ━━━━━━━━━━━━━━━━━━━━ 4:05 104ms/step - accuracy: 0.5735 - loss: 0.7737Batch 140: accuracy=0.6234, loss=0.7190
#  149/2500 ━━━━━━━━━━━━━━━━━━━━ 4:04 104ms/step - accuracy: 0.5769 - loss: 0.7700Batch 150: accuracy=0.6254, loss=0.7159
#  159/2500 ━━━━━━━━━━━━━━━━━━━━ 4:03 104ms/step - accuracy: 0.5800 - loss: 0.7665Batch 160: accuracy=0.6281, loss=0.7120
#  169/2500 ━━━━━━━━━━━━━━━━━━━━ 4:02 104ms/step - accuracy: 0.5830 - loss: 0.7631Batch 170: accuracy=0.6324, loss=0.7035
#  179/2500 ━━━━━━━━━━━━━━━━━━━━ 4:01 104ms/step - accuracy: 0.5858 - loss: 0.7596Batch 180: accuracy=0.6363, loss=0.6985
#  189/2500 ━━━━━━━━━━━━━━━━━━━━ 4:00 104ms/step - accuracy: 0.5885 - loss: 0.7563Batch 190: accuracy=0.6370, loss=0.6961
#  199/2500 ━━━━━━━━━━━━━━━━━━━━ 3:59 104ms/step - accuracy: 0.5910 - loss: 0.7532Batch 200: accuracy=0.6398, loss=0.6897
#  209/2500 ━━━━━━━━━━━━━━━━━━━━ 3:58 104ms/step - accuracy: 0.5934 - loss: 0.7500Batch 210: accuracy=0.6429, loss=0.6868
#  219/2500 ━━━━━━━━━━━━━━━━━━━━ 3:57 104ms/step - accuracy: 0.5957 - loss: 0.7471Batch 220: accuracy=0.6460, loss=0.6837
#  229/2500 ━━━━━━━━━━━━━━━━━━━━ 3:56 104ms/step - accuracy: 0.5979 - loss: 0.7442Batch 230: accuracy=0.6467, loss=0.6809
#  239/2500 ━━━━━━━━━━━━━━━━━━━━ 3:56 104ms/step - accuracy: 0.6000 - loss: 0.7416Batch 240: accuracy=0.6490, loss=0.6789
#  249/2500 ━━━━━━━━━━━━━━━━━━━━ 3:55 104ms/step - accuracy: 0.6020 - loss: 0.7390Batch 250: accuracy=0.6500, loss=0.6775
#  259/2500 ━━━━━━━━━━━━━━━━━━━━ 3:54 104ms/step - accuracy: 0.6039 - loss: 0.7365Batch 260: accuracy=0.6536, loss=0.6718
#  269/2500 ━━━━━━━━━━━━━━━━━━━━ 3:53 105ms/step - accuracy: 0.6058 - loss: 0.7341Batch 270: accuracy=0.6550, loss=0.6702
#  279/2500 ━━━━━━━━━━━━━━━━━━━━ 3:52 105ms/step - accuracy: 0.6076 - loss: 0.7318Batch 280: accuracy=0.6569, loss=0.6679
#  289/2500 ━━━━━━━━━━━━━━━━━━━━ 3:51 105ms/step - accuracy: 0.6093 - loss: 0.7295Batch 290: accuracy=0.6596, loss=0.6631
#  299/2500 ━━━━━━━━━━━━━━━━━━━━ 3:50 105ms/step - accuracy: 0.6110 - loss: 0.7273Batch 300: accuracy=0.6610, loss=0.6618
#  309/2500 ━━━━━━━━━━━━━━━━━━━━ 3:49 105ms/step - accuracy: 0.6127 - loss: 0.7251Batch 310: accuracy=0.6621, loss=0.6592
#  319/2500 ━━━━━━━━━━━━━━━━━━━━ 3:48 105ms/step - accuracy: 0.6143 - loss: 0.7230Batch 320: accuracy=0.6647, loss=0.6565
#  329/2500 ━━━━━━━━━━━━━━━━━━━━ 3:47 105ms/step - accuracy: 0.6158 - loss: 0.7210Batch 330: accuracy=0.6645, loss=0.6566
#  339/2500 ━━━━━━━━━━━━━━━━━━━━ 3:46 105ms/step - accuracy: 0.6173 - loss: 0.7190Batch 340: accuracy=0.6659, loss=0.6533
#  349/2500 ━━━━━━━━━━━━━━━━━━━━ 3:45 105ms/step - accuracy: 0.6187 - loss: 0.7171Batch 350: accuracy=0.6679, loss=0.6493
#  359/2500 ━━━━━━━━━━━━━━━━━━━━ 3:45 105ms/step - accuracy: 0.6201 - loss: 0.7152Batch 360: accuracy=0.6700, loss=0.6465
#  369/2500 ━━━━━━━━━━━━━━━━━━━━ 3:44 105ms/step - accuracy: 0.6215 - loss: 0.7133Batch 370: accuracy=0.6727, loss=0.6426
#  379/2500 ━━━━━━━━━━━━━━━━━━━━ 3:43 105ms/step - accuracy: 0.6228 - loss: 0.7114Batch 380: accuracy=0.6744, loss=0.6409
#  389/2500 ━━━━━━━━━━━━━━━━━━━━ 3:42 105ms/step - accuracy: 0.6242 - loss: 0.7096Batch 390: accuracy=0.6744, loss=0.6414
#  399/2500 ━━━━━━━━━━━━━━━━━━━━ 3:41 105ms/step - accuracy: 0.6254 - loss: 0.7079Batch 400: accuracy=0.6749, loss=0.6404
#  409/2500 ━━━━━━━━━━━━━━━━━━━━ 3:40 105ms/step - accuracy: 0.6266 - loss: 0.7062Batch 410: accuracy=0.6761, loss=0.6392
#  419/2500 ━━━━━━━━━━━━━━━━━━━━ 3:39 106ms/step - accuracy: 0.6278 - loss: 0.7046Batch 420: accuracy=0.6768, loss=0.6373
#  429/2500 ━━━━━━━━━━━━━━━━━━━━ 3:38 106ms/step - accuracy: 0.6290 - loss: 0.7030Batch 430: accuracy=0.6773, loss=0.6370
#  439/2500 ━━━━━━━━━━━━━━━━━━━━ 3:37 106ms/step - accuracy: 0.6301 - loss: 0.7015Batch 440: accuracy=0.6786, loss=0.6350
#  449/2500 ━━━━━━━━━━━━━━━━━━━━ 3:37 106ms/step - accuracy: 0.6312 - loss: 0.7000Batch 450: accuracy=0.6785, loss=0.6359
#  459/2500 ━━━━━━━━━━━━━━━━━━━━ 3:36 106ms/step - accuracy: 0.6322 - loss: 0.6986Batch 460: accuracy=0.6789, loss=0.6347
#  469/2500 ━━━━━━━━━━━━━━━━━━━━ 3:35 106ms/step - accuracy: 0.6332 - loss: 0.6972Batch 470: accuracy=0.6797, loss=0.6335
#  479/2500 ━━━━━━━━━━━━━━━━━━━━ 3:34 106ms/step - accuracy: 0.6342 - loss: 0.6959Batch 480: accuracy=0.6802, loss=0.6329
#  489/2500 ━━━━━━━━━━━━━━━━━━━━ 3:33 106ms/step - accuracy: 0.6351 - loss: 0.6946Batch 490: accuracy=0.6812, loss=0.6309
#  499/2500 ━━━━━━━━━━━━━━━━━━━━ 3:32 106ms/step - accuracy: 0.6361 - loss: 0.6933Batch 500: accuracy=0.6826, loss=0.6287
#  509/2500 ━━━━━━━━━━━━━━━━━━━━ 3:31 106ms/step - accuracy: 0.6370 - loss: 0.6920Batch 510: accuracy=0.6833, loss=0.6284
#  519/2500 ━━━━━━━━━━━━━━━━━━━━ 3:30 106ms/step - accuracy: 0.6379 - loss: 0.6908Batch 520: accuracy=0.6837, loss=0.6280
#  529/2500 ━━━━━━━━━━━━━━━━━━━━ 3:29 106ms/step - accuracy: 0.6388 - loss: 0.6896Batch 530: accuracy=0.6841, loss=0.6270
#  539/2500 ━━━━━━━━━━━━━━━━━━━━ 3:28 107ms/step - accuracy: 0.6396 - loss: 0.6884Batch 540: accuracy=0.6846, loss=0.6258
#  549/2500 ━━━━━━━━━━━━━━━━━━━━ 3:27 107ms/step - accuracy: 0.6404 - loss: 0.6873Batch 550: accuracy=0.6853, loss=0.6241
#  559/2500 ━━━━━━━━━━━━━━━━━━━━ 3:27 107ms/step - accuracy: 0.6412 - loss: 0.6861Batch 560: accuracy=0.6858, loss=0.6232
#  569/2500 ━━━━━━━━━━━━━━━━━━━━ 3:26 107ms/step - accuracy: 0.6420 - loss: 0.6850Batch 570: accuracy=0.6864, loss=0.6222
#  579/2500 ━━━━━━━━━━━━━━━━━━━━ 3:25 107ms/step - accuracy: 0.6428 - loss: 0.6839Batch 580: accuracy=0.6869, loss=0.6202
#  589/2500 ━━━━━━━━━━━━━━━━━━━━ 3:24 107ms/step - accuracy: 0.6435 - loss: 0.6828Batch 590: accuracy=0.6876, loss=0.6195
#  599/2500 ━━━━━━━━━━━━━━━━━━━━ 3:23 107ms/step - accuracy: 0.6443 - loss: 0.6818Batch 600: accuracy=0.6884, loss=0.6183
#  609/2500 ━━━━━━━━━━━━━━━━━━━━ 3:22 107ms/step - accuracy: 0.6450 - loss: 0.6807Batch 610: accuracy=0.6892, loss=0.6171
#  619/2500 ━━━━━━━━━━━━━━━━━━━━ 3:21 107ms/step - accuracy: 0.6457 - loss: 0.6797Batch 620: accuracy=0.6898, loss=0.6168
#  629/2500 ━━━━━━━━━━━━━━━━━━━━ 3:20 107ms/step - accuracy: 0.6464 - loss: 0.6787Batch 630: accuracy=0.6910, loss=0.6154
#  639/2500 ━━━━━━━━━━━━━━━━━━━━ 3:19 107ms/step - accuracy: 0.6471 - loss: 0.6777Batch 640: accuracy=0.6913, loss=0.6146
#  649/2500 ━━━━━━━━━━━━━━━━━━━━ 3:18 107ms/step - accuracy: 0.6478 - loss: 0.6767Batch 650: accuracy=0.6922, loss=0.6131
#  659/2500 ━━━━━━━━━━━━━━━━━━━━ 3:17 107ms/step - accuracy: 0.6485 - loss: 0.6757Batch 660: accuracy=0.6925, loss=0.6123
#  669/2500 ━━━━━━━━━━━━━━━━━━━━ 3:16 107ms/step - accuracy: 0.6492 - loss: 0.6748Batch 670: accuracy=0.6925, loss=0.6124
#  679/2500 ━━━━━━━━━━━━━━━━━━━━ 3:15 108ms/step - accuracy: 0.6498 - loss: 0.6739Batch 680: accuracy=0.6932, loss=0.6112
#  689/2500 ━━━━━━━━━━━━━━━━━━━━ 3:14 108ms/step - accuracy: 0.6504 - loss: 0.6729Batch 690: accuracy=0.6935, loss=0.6112
#  699/2500 ━━━━━━━━━━━━━━━━━━━━ 3:13 108ms/step - accuracy: 0.6511 - loss: 0.6721Batch 700: accuracy=0.6938, loss=0.6107
#  709/2500 ━━━━━━━━━━━━━━━━━━━━ 3:13 108ms/step - accuracy: 0.6517 - loss: 0.6712Batch 710: accuracy=0.6941, loss=0.6102
#  719/2500 ━━━━━━━━━━━━━━━━━━━━ 3:12 108ms/step - accuracy: 0.6523 - loss: 0.6703Batch 720: accuracy=0.6948, loss=0.6088
#  729/2500 ━━━━━━━━━━━━━━━━━━━━ 3:11 108ms/step - accuracy: 0.6528 - loss: 0.6695Batch 730: accuracy=0.6955, loss=0.6073
#  739/2500 ━━━━━━━━━━━━━━━━━━━━ 3:10 108ms/step - accuracy: 0.6534 - loss: 0.6686Batch 740: accuracy=0.6963, loss=0.6063
#  749/2500 ━━━━━━━━━━━━━━━━━━━━ 3:09 108ms/step - accuracy: 0.6540 - loss: 0.6678Batch 750: accuracy=0.6964, loss=0.6057
#  759/2500 ━━━━━━━━━━━━━━━━━━━━ 3:08 108ms/step - accuracy: 0.6546 - loss: 0.6670Batch 760: accuracy=0.6964, loss=0.6052
#  769/2500 ━━━━━━━━━━━━━━━━━━━━ 3:07 108ms/step - accuracy: 0.6551 - loss: 0.6662Batch 770: accuracy=0.6969, loss=0.6045
#  779/2500 ━━━━━━━━━━━━━━━━━━━━ 3:06 108ms/step - accuracy: 0.6556 - loss: 0.6654Batch 780: accuracy=0.6976, loss=0.6039
#  789/2500 ━━━━━━━━━━━━━━━━━━━━ 3:05 108ms/step - accuracy: 0.6562 - loss: 0.6646Batch 790: accuracy=0.6979, loss=0.6030
#  799/2500 ━━━━━━━━━━━━━━━━━━━━ 3:04 108ms/step - accuracy: 0.6567 - loss: 0.6638Batch 800: accuracy=0.6983, loss=0.6022
#  809/2500 ━━━━━━━━━━━━━━━━━━━━ 3:03 108ms/step - accuracy: 0.6572 - loss: 0.6630Batch 810: accuracy=0.6986, loss=0.6016
#  819/2500 ━━━━━━━━━━━━━━━━━━━━ 3:02 109ms/step - accuracy: 0.6577 - loss: 0.6623Batch 820: accuracy=0.6994, loss=0.6003
#  829/2500 ━━━━━━━━━━━━━━━━━━━━ 3:01 109ms/step - accuracy: 0.6582 - loss: 0.6615Batch 830: accuracy=0.7001, loss=0.5994
#  839/2500 ━━━━━━━━━━━━━━━━━━━━ 3:00 109ms/step - accuracy: 0.6587 - loss: 0.6608Batch 840: accuracy=0.7008, loss=0.5981
#  849/2500 ━━━━━━━━━━━━━━━━━━━━ 2:59 109ms/step - accuracy: 0.6592 - loss: 0.6601Batch 850: accuracy=0.7010, loss=0.5974
#  859/2500 ━━━━━━━━━━━━━━━━━━━━ 2:58 109ms/step - accuracy: 0.6597 - loss: 0.6593Batch 860: accuracy=0.7012, loss=0.5972
#  869/2500 ━━━━━━━━━━━━━━━━━━━━ 2:57 109ms/step - accuracy: 0.6602 - loss: 0.6586Batch 870: accuracy=0.7015, loss=0.5967
#  879/2500 ━━━━━━━━━━━━━━━━━━━━ 2:56 109ms/step - accuracy: 0.6607 - loss: 0.6579Batch 880: accuracy=0.7018, loss=0.5961
#  889/2500 ━━━━━━━━━━━━━━━━━━━━ 2:55 109ms/step - accuracy: 0.6611 - loss: 0.6572Batch 890: accuracy=0.7025, loss=0.5950
#  899/2500 ━━━━━━━━━━━━━━━━━━━━ 2:54 109ms/step - accuracy: 0.6616 - loss: 0.6565Batch 900: accuracy=0.7029, loss=0.5946
#  909/2500 ━━━━━━━━━━━━━━━━━━━━ 2:53 109ms/step - accuracy: 0.6621 - loss: 0.6558Batch 910: accuracy=0.7032, loss=0.5940
#  919/2500 ━━━━━━━━━━━━━━━━━━━━ 2:52 109ms/step - accuracy: 0.6625 - loss: 0.6551Batch 920: accuracy=0.7032, loss=0.5940
#  929/2500 ━━━━━━━━━━━━━━━━━━━━ 2:51 109ms/step - accuracy: 0.6629 - loss: 0.6545Batch 930: accuracy=0.7038, loss=0.5927
#  939/2500 ━━━━━━━━━━━━━━━━━━━━ 2:50 109ms/step - accuracy: 0.6634 - loss: 0.6538Batch 940: accuracy=0.7046, loss=0.5916
#  949/2500 ━━━━━━━━━━━━━━━━━━━━ 2:49 109ms/step - accuracy: 0.6638 - loss: 0.6532Batch 950: accuracy=0.7045, loss=0.5912
#  959/2500 ━━━━━━━━━━━━━━━━━━━━ 2:48 110ms/step - accuracy: 0.6642 - loss: 0.6525Batch 960: accuracy=0.7048, loss=0.5910
#  969/2500 ━━━━━━━━━━━━━━━━━━━━ 2:47 110ms/step - accuracy: 0.6647 - loss: 0.6519Batch 970: accuracy=0.7055, loss=0.5902
#  979/2500 ━━━━━━━━━━━━━━━━━━━━ 2:46 110ms/step - accuracy: 0.6651 - loss: 0.6512Batch 980: accuracy=0.7057, loss=0.5896
#  989/2500 ━━━━━━━━━━━━━━━━━━━━ 2:45 110ms/step - accuracy: 0.6655 - loss: 0.6506Batch 990: accuracy=0.7057, loss=0.5896
#  999/2500 ━━━━━━━━━━━━━━━━━━━━ 2:44 110ms/step - accuracy: 0.6659 - loss: 0.6500Batch 1000: accuracy=0.7060, loss=0.5893
# 1009/2500 ━━━━━━━━━━━━━━━━━━━━ 2:43 110ms/step - accuracy: 0.6663 - loss: 0.6494Batch 1010: accuracy=0.7063, loss=0.5890
# 1019/2500 ━━━━━━━━━━━━━━━━━━━━ 2:42 110ms/step - accuracy: 0.6667 - loss: 0.6488Batch 1020: accuracy=0.7067, loss=0.5882
# 1029/2500 ━━━━━━━━━━━━━━━━━━━━ 2:41 110ms/step - accuracy: 0.6671 - loss: 0.6482Batch 1030: accuracy=0.7070, loss=0.5875
# 1039/2500 ━━━━━━━━━━━━━━━━━━━━ 2:40 110ms/step - accuracy: 0.6675 - loss: 0.6476Batch 1040: accuracy=0.7069, loss=0.5872
# 1049/2500 ━━━━━━━━━━━━━━━━━━━━ 2:39 110ms/step - accuracy: 0.6678 - loss: 0.6471Batch 1050: accuracy=0.7069, loss=0.5872
# 1059/2500 ━━━━━━━━━━━━━━━━━━━━ 2:38 110ms/step - accuracy: 0.6682 - loss: 0.6465Batch 1060: accuracy=0.7075, loss=0.5864
# 1069/2500 ━━━━━━━━━━━━━━━━━━━━ 2:37 110ms/step - accuracy: 0.6686 - loss: 0.6459Batch 1070: accuracy=0.7078, loss=0.5861
# 1079/2500 ━━━━━━━━━━━━━━━━━━━━ 2:36 110ms/step - accuracy: 0.6689 - loss: 0.6454Batch 1080: accuracy=0.7080, loss=0.5859
# 1089/2500 ━━━━━━━━━━━━━━━━━━━━ 2:35 110ms/step - accuracy: 0.6693 - loss: 0.6448Batch 1090: accuracy=0.7084, loss=0.5856
# 1099/2500 ━━━━━━━━━━━━━━━━━━━━ 2:34 110ms/step - accuracy: 0.6697 - loss: 0.6443Batch 1100: accuracy=0.7088, loss=0.5849
# 1109/2500 ━━━━━━━━━━━━━━━━━━━━ 2:33 110ms/step - accuracy: 0.6700 - loss: 0.6437Batch 1110: accuracy=0.7086, loss=0.5851
# 1119/2500 ━━━━━━━━━━━━━━━━━━━━ 2:32 110ms/step - accuracy: 0.6704 - loss: 0.6432Batch 1120: accuracy=0.7089, loss=0.5846
# 1129/2500 ━━━━━━━━━━━━━━━━━━━━ 2:31 110ms/step - accuracy: 0.6707 - loss: 0.6427Batch 1130: accuracy=0.7092, loss=0.5843
# 1139/2500 ━━━━━━━━━━━━━━━━━━━━ 2:29 110ms/step - accuracy: 0.6710 - loss: 0.6422Batch 1140: accuracy=0.7095, loss=0.5838
# 1149/2500 ━━━━━━━━━━━━━━━━━━━━ 2:28 110ms/step - accuracy: 0.6714 - loss: 0.6417Batch 1150: accuracy=0.7096, loss=0.5835
# 1159/2500 ━━━━━━━━━━━━━━━━━━━━ 2:27 110ms/step - accuracy: 0.6717 - loss: 0.6412Batch 1160: accuracy=0.7102, loss=0.5825
# 1169/2500 ━━━━━━━━━━━━━━━━━━━━ 2:26 110ms/step - accuracy: 0.6720 - loss: 0.6407Batch 1170: accuracy=0.7105, loss=0.5821
# 1179/2500 ━━━━━━━━━━━━━━━━━━━━ 2:25 110ms/step - accuracy: 0.6724 - loss: 0.6402Batch 1180: accuracy=0.7108, loss=0.5817
# 1189/2500 ━━━━━━━━━━━━━━━━━━━━ 2:24 110ms/step - accuracy: 0.6727 - loss: 0.6397Batch 1190: accuracy=0.7112, loss=0.5814
# 1199/2500 ━━━━━━━━━━━━━━━━━━━━ 2:23 110ms/step - accuracy: 0.6730 - loss: 0.6392Batch 1200: accuracy=0.7113, loss=0.5814
# 1209/2500 ━━━━━━━━━━━━━━━━━━━━ 2:22 110ms/step - accuracy: 0.6733 - loss: 0.6387Batch 1210: accuracy=0.7120, loss=0.5806
# 1219/2500 ━━━━━━━━━━━━━━━━━━━━ 2:21 110ms/step - accuracy: 0.6736 - loss: 0.6382Batch 1220: accuracy=0.7119, loss=0.5809
# 1229/2500 ━━━━━━━━━━━━━━━━━━━━ 2:20 110ms/step - accuracy: 0.6740 - loss: 0.6378Batch 1230: accuracy=0.7117, loss=0.5807
# 1239/2500 ━━━━━━━━━━━━━━━━━━━━ 2:19 110ms/step - accuracy: 0.6743 - loss: 0.6373Batch 1240: accuracy=0.7123, loss=0.5798
# 1249/2500 ━━━━━━━━━━━━━━━━━━━━ 2:18 110ms/step - accuracy: 0.6746 - loss: 0.6368Batch 1250: accuracy=0.7127, loss=0.5792
# 1259/2500 ━━━━━━━━━━━━━━━━━━━━ 2:17 110ms/step - accuracy: 0.6749 - loss: 0.6364Batch 1260: accuracy=0.7130, loss=0.5785
# 1269/2500 ━━━━━━━━━━━━━━━━━━━━ 2:15 110ms/step - accuracy: 0.6752 - loss: 0.6359Batch 1270: accuracy=0.7133, loss=0.5781
# 1279/2500 ━━━━━━━━━━━━━━━━━━━━ 2:14 110ms/step - accuracy: 0.6755 - loss: 0.6355Batch 1280: accuracy=0.7134, loss=0.5778
# 1289/2500 ━━━━━━━━━━━━━━━━━━━━ 2:13 110ms/step - accuracy: 0.6758 - loss: 0.6350Batch 1290: accuracy=0.7137, loss=0.5772
# 1299/2500 ━━━━━━━━━━━━━━━━━━━━ 2:12 110ms/step - accuracy: 0.6761 - loss: 0.6346Batch 1300: accuracy=0.7137, loss=0.5779
# 1309/2500 ━━━━━━━━━━━━━━━━━━━━ 2:11 111ms/step - accuracy: 0.6763 - loss: 0.6341Batch 1310: accuracy=0.7136, loss=0.5782
# 1319/2500 ━━━━━━━━━━━━━━━━━━━━ 2:10 111ms/step - accuracy: 0.6766 - loss: 0.6337Batch 1320: accuracy=0.7139, loss=0.5775
# 1329/2500 ━━━━━━━━━━━━━━━━━━━━ 2:09 111ms/step - accuracy: 0.6769 - loss: 0.6333Batch 1330: accuracy=0.7139, loss=0.5771
# 1339/2500 ━━━━━━━━━━━━━━━━━━━━ 2:08 111ms/step - accuracy: 0.6772 - loss: 0.6329Batch 1340: accuracy=0.7138, loss=0.5772
# 1349/2500 ━━━━━━━━━━━━━━━━━━━━ 2:07 111ms/step - accuracy: 0.6775 - loss: 0.6325Batch 1350: accuracy=0.7139, loss=0.5771
# 1359/2500 ━━━━━━━━━━━━━━━━━━━━ 2:06 111ms/step - accuracy: 0.6777 - loss: 0.6320Batch 1360: accuracy=0.7140, loss=0.5767
# 1369/2500 ━━━━━━━━━━━━━━━━━━━━ 2:05 111ms/step - accuracy: 0.6780 - loss: 0.6316Batch 1370: accuracy=0.7145, loss=0.5760
# 1379/2500 ━━━━━━━━━━━━━━━━━━━━ 2:04 111ms/step - accuracy: 0.6783 - loss: 0.6312Batch 1380: accuracy=0.7145, loss=0.5762
# 1389/2500 ━━━━━━━━━━━━━━━━━━━━ 2:02 111ms/step - accuracy: 0.6785 - loss: 0.6308Batch 1390: accuracy=0.7146, loss=0.5759
# 1399/2500 ━━━━━━━━━━━━━━━━━━━━ 2:01 111ms/step - accuracy: 0.6788 - loss: 0.6304Batch 1400: accuracy=0.7151, loss=0.5754
# 1409/2500 ━━━━━━━━━━━━━━━━━━━━ 2:00 111ms/step - accuracy: 0.6790 - loss: 0.6301Batch 1410: accuracy=0.7152, loss=0.5756
# 1419/2500 ━━━━━━━━━━━━━━━━━━━━ 1:59 111ms/step - accuracy: 0.6793 - loss: 0.6297Batch 1420: accuracy=0.7155, loss=0.5750
# 1429/2500 ━━━━━━━━━━━━━━━━━━━━ 1:58 111ms/step - accuracy: 0.6795 - loss: 0.6293Batch 1430: accuracy=0.7156, loss=0.5745
# 1439/2500 ━━━━━━━━━━━━━━━━━━━━ 1:57 111ms/step - accuracy: 0.6798 - loss: 0.6289Batch 1440: accuracy=0.7159, loss=0.5744
# 1449/2500 ━━━━━━━━━━━━━━━━━━━━ 1:56 111ms/step - accuracy: 0.6800 - loss: 0.6285Batch 1450: accuracy=0.7160, loss=0.5741
# 1459/2500 ━━━━━━━━━━━━━━━━━━━━ 1:55 111ms/step - accuracy: 0.6803 - loss: 0.6282Batch 1460: accuracy=0.7162, loss=0.5737
# 1469/2500 ━━━━━━━━━━━━━━━━━━━━ 1:54 111ms/step - accuracy: 0.6805 - loss: 0.6278Batch 1470: accuracy=0.7164, loss=0.5735
# 1479/2500 ━━━━━━━━━━━━━━━━━━━━ 1:53 111ms/step - accuracy: 0.6808 - loss: 0.6274Batch 1480: accuracy=0.7164, loss=0.5732
# 1489/2500 ━━━━━━━━━━━━━━━━━━━━ 1:52 111ms/step - accuracy: 0.6810 - loss: 0.6271Batch 1490: accuracy=0.7166, loss=0.5732
# 1499/2500 ━━━━━━━━━━━━━━━━━━━━ 1:50 111ms/step - accuracy: 0.6813 - loss: 0.6267Batch 1500: accuracy=0.7167, loss=0.5733
# 1509/2500 ━━━━━━━━━━━━━━━━━━━━ 1:49 111ms/step - accuracy: 0.6815 - loss: 0.6263Batch 1510: accuracy=0.7167, loss=0.5729
# 1519/2500 ━━━━━━━━━━━━━━━━━━━━ 1:48 111ms/step - accuracy: 0.6817 - loss: 0.6260Batch 1520: accuracy=0.7169, loss=0.5726
# 1529/2500 ━━━━━━━━━━━━━━━━━━━━ 1:47 111ms/step - accuracy: 0.6820 - loss: 0.6256Batch 1530: accuracy=0.7169, loss=0.5729
# 1539/2500 ━━━━━━━━━━━━━━━━━━━━ 1:46 111ms/step - accuracy: 0.6822 - loss: 0.6253Batch 1540: accuracy=0.7169, loss=0.5728
# 1549/2500 ━━━━━━━━━━━━━━━━━━━━ 1:45 111ms/step - accuracy: 0.6824 - loss: 0.6250Batch 1550: accuracy=0.7171, loss=0.5728
# 1559/2500 ━━━━━━━━━━━━━━━━━━━━ 1:44 111ms/step - accuracy: 0.6826 - loss: 0.6246Batch 1560: accuracy=0.7171, loss=0.5726
# 1569/2500 ━━━━━━━━━━━━━━━━━━━━ 1:43 111ms/step - accuracy: 0.6829 - loss: 0.6243Batch 1570: accuracy=0.7173, loss=0.5722
# 1579/2500 ━━━━━━━━━━━━━━━━━━━━ 1:42 111ms/step - accuracy: 0.6831 - loss: 0.6240Batch 1580: accuracy=0.7174, loss=0.5722
# 1589/2500 ━━━━━━━━━━━━━━━━━━━━ 1:41 111ms/step - accuracy: 0.6833 - loss: 0.6236Batch 1590: accuracy=0.7175, loss=0.5721
# 1599/2500 ━━━━━━━━━━━━━━━━━━━━ 1:39 111ms/step - accuracy: 0.6835 - loss: 0.6233Batch 1600: accuracy=0.7173, loss=0.5719
# 1609/2500 ━━━━━━━━━━━━━━━━━━━━ 1:38 111ms/step - accuracy: 0.6837 - loss: 0.6230Batch 1610: accuracy=0.7175, loss=0.5717
# 1619/2500 ━━━━━━━━━━━━━━━━━━━━ 1:37 111ms/step - accuracy: 0.6839 - loss: 0.6227Batch 1620: accuracy=0.7177, loss=0.5716
# 1629/2500 ━━━━━━━━━━━━━━━━━━━━ 1:36 111ms/step - accuracy: 0.6841 - loss: 0.6224Batch 1630: accuracy=0.7176, loss=0.5716
# 1639/2500 ━━━━━━━━━━━━━━━━━━━━ 1:35 111ms/step - accuracy: 0.6843 - loss: 0.6220Batch 1640: accuracy=0.7178, loss=0.5712
# 1649/2500 ━━━━━━━━━━━━━━━━━━━━ 1:34 111ms/step - accuracy: 0.6845 - loss: 0.6217Batch 1650: accuracy=0.7179, loss=0.5710
# 1659/2500 ━━━━━━━━━━━━━━━━━━━━ 1:33 111ms/step - accuracy: 0.6847 - loss: 0.6214Batch 1660: accuracy=0.7180, loss=0.5708
# 1669/2500 ━━━━━━━━━━━━━━━━━━━━ 1:32 111ms/step - accuracy: 0.6849 - loss: 0.6211Batch 1670: accuracy=0.7182, loss=0.5703
# 1679/2500 ━━━━━━━━━━━━━━━━━━━━ 1:31 111ms/step - accuracy: 0.6851 - loss: 0.6208Batch 1680: accuracy=0.7185, loss=0.5699
# 1689/2500 ━━━━━━━━━━━━━━━━━━━━ 1:30 111ms/step - accuracy: 0.6853 - loss: 0.6205Batch 1690: accuracy=0.7187, loss=0.5695
# 1699/2500 ━━━━━━━━━━━━━━━━━━━━ 1:29 111ms/step - accuracy: 0.6855 - loss: 0.6202Batch 1700: accuracy=0.7187, loss=0.5693
# 1709/2500 ━━━━━━━━━━━━━━━━━━━━ 1:27 111ms/step - accuracy: 0.6857 - loss: 0.6199Batch 1710: accuracy=0.7191, loss=0.5688
# 1719/2500 ━━━━━━━━━━━━━━━━━━━━ 1:26 111ms/step - accuracy: 0.6859 - loss: 0.6196Batch 1720: accuracy=0.7191, loss=0.5688
# 1729/2500 ━━━━━━━━━━━━━━━━━━━━ 1:25 111ms/step - accuracy: 0.6861 - loss: 0.6193Batch 1730: accuracy=0.7190, loss=0.5687
# 1739/2500 ━━━━━━━━━━━━━━━━━━━━ 1:24 111ms/step - accuracy: 0.6863 - loss: 0.6190Batch 1740: accuracy=0.7191, loss=0.5687
# 1749/2500 ━━━━━━━━━━━━━━━━━━━━ 1:23 111ms/step - accuracy: 0.6865 - loss: 0.6188Batch 1750: accuracy=0.7190, loss=0.5685
# 1759/2500 ━━━━━━━━━━━━━━━━━━━━ 1:22 111ms/step - accuracy: 0.6867 - loss: 0.6185Batch 1760: accuracy=0.7191, loss=0.5682
# 1769/2500 ━━━━━━━━━━━━━━━━━━━━ 1:21 111ms/step - accuracy: 0.6869 - loss: 0.6182Batch 1770: accuracy=0.7193, loss=0.5680
# 1779/2500 ━━━━━━━━━━━━━━━━━━━━ 1:20 111ms/step - accuracy: 0.6870 - loss: 0.6179Batch 1780: accuracy=0.7194, loss=0.5677
# 1789/2500 ━━━━━━━━━━━━━━━━━━━━ 1:19 111ms/step - accuracy: 0.6872 - loss: 0.6176Batch 1790: accuracy=0.7194, loss=0.5678
# 1799/2500 ━━━━━━━━━━━━━━━━━━━━ 1:17 111ms/step - accuracy: 0.6874 - loss: 0.6173Batch 1800: accuracy=0.7194, loss=0.5677
# 1809/2500 ━━━━━━━━━━━━━━━━━━━━ 1:16 111ms/step - accuracy: 0.6876 - loss: 0.6171Batch 1810: accuracy=0.7197, loss=0.5675
# 1819/2500 ━━━━━━━━━━━━━━━━━━━━ 1:15 111ms/step - accuracy: 0.6878 - loss: 0.6168Batch 1820: accuracy=0.7196, loss=0.5675
# 1829/2500 ━━━━━━━━━━━━━━━━━━━━ 1:14 111ms/step - accuracy: 0.6879 - loss: 0.6165Batch 1830: accuracy=0.7198, loss=0.5672
# 1839/2500 ━━━━━━━━━━━━━━━━━━━━ 1:13 111ms/step - accuracy: 0.6881 - loss: 0.6163Batch 1840: accuracy=0.7199, loss=0.5672
# 1849/2500 ━━━━━━━━━━━━━━━━━━━━ 1:12 111ms/step - accuracy: 0.6883 - loss: 0.6160Batch 1850: accuracy=0.7200, loss=0.5669
# 1859/2500 ━━━━━━━━━━━━━━━━━━━━ 1:11 111ms/step - accuracy: 0.6884 - loss: 0.6157Batch 1860: accuracy=0.7202, loss=0.5665
# 1869/2500 ━━━━━━━━━━━━━━━━━━━━ 1:10 111ms/step - accuracy: 0.6886 - loss: 0.6155Batch 1870: accuracy=0.7204, loss=0.5664
# 1879/2500 ━━━━━━━━━━━━━━━━━━━━ 1:09 111ms/step - accuracy: 0.6888 - loss: 0.6152Batch 1880: accuracy=0.7205, loss=0.5663
# 1889/2500 ━━━━━━━━━━━━━━━━━━━━ 1:08 111ms/step - accuracy: 0.6890 - loss: 0.6149Batch 1890: accuracy=0.7207, loss=0.5658
# 1899/2500 ━━━━━━━━━━━━━━━━━━━━ 1:06 111ms/step - accuracy: 0.6891 - loss: 0.6147Batch 1900: accuracy=0.7207, loss=0.5658
# 1909/2500 ━━━━━━━━━━━━━━━━━━━━ 1:05 111ms/step - accuracy: 0.6893 - loss: 0.6144Batch 1910: accuracy=0.7209, loss=0.5656
# 1919/2500 ━━━━━━━━━━━━━━━━━━━━ 1:04 111ms/step - accuracy: 0.6895 - loss: 0.6142Batch 1920: accuracy=0.7209, loss=0.5657
# 1929/2500 ━━━━━━━━━━━━━━━━━━━━ 1:03 111ms/step - accuracy: 0.6896 - loss: 0.6139Batch 1930: accuracy=0.7210, loss=0.5654
# 1939/2500 ━━━━━━━━━━━━━━━━━━━━ 1:02 111ms/step - accuracy: 0.6898 - loss: 0.6137Batch 1940: accuracy=0.7212, loss=0.5655
# 1949/2500 ━━━━━━━━━━━━━━━━━━━━ 1:01 111ms/step - accuracy: 0.6899 - loss: 0.6134Batch 1950: accuracy=0.7214, loss=0.5652
# 1959/2500 ━━━━━━━━━━━━━━━━━━━━ 1:00 111ms/step - accuracy: 0.6901 - loss: 0.6132Batch 1960: accuracy=0.7215, loss=0.5651
# 1969/2500 ━━━━━━━━━━━━━━━━━━━━ 59s 111ms/step - accuracy: 0.6903 - loss: 0.6129Batch 1970: accuracy=0.7216, loss=0.5648
# 1979/2500 ━━━━━━━━━━━━━━━━━━━━ 58s 111ms/step - accuracy: 0.6904 - loss: 0.6127Batch 1980: accuracy=0.7218, loss=0.5645
# 1989/2500 ━━━━━━━━━━━━━━━━━━━━ 56s 111ms/step - accuracy: 0.6906 - loss: 0.6124Batch 1990: accuracy=0.7218, loss=0.5643
# 1999/2500 ━━━━━━━━━━━━━━━━━━━━ 55s 111ms/step - accuracy: 0.6907 - loss: 0.6122Batch 2000: accuracy=0.7219, loss=0.5642
# 2009/2500 ━━━━━━━━━━━━━━━━━━━━ 54s 111ms/step - accuracy: 0.6909 - loss: 0.6120Batch 2010: accuracy=0.7221, loss=0.5639
# 2019/2500 ━━━━━━━━━━━━━━━━━━━━ 53s 111ms/step - accuracy: 0.6910 - loss: 0.6117Batch 2020: accuracy=0.7223, loss=0.5638
# 2029/2500 ━━━━━━━━━━━━━━━━━━━━ 52s 111ms/step - accuracy: 0.6912 - loss: 0.6115Batch 2030: accuracy=0.7223, loss=0.5639
# 2039/2500 ━━━━━━━━━━━━━━━━━━━━ 51s 112ms/step - accuracy: 0.6913 - loss: 0.6113Batch 2040: accuracy=0.7224, loss=0.5638
# 2049/2500 ━━━━━━━━━━━━━━━━━━━━ 50s 112ms/step - accuracy: 0.6915 - loss: 0.6110Batch 2050: accuracy=0.7224, loss=0.5637
# 2059/2500 ━━━━━━━━━━━━━━━━━━━━ 49s 112ms/step - accuracy: 0.6916 - loss: 0.6108Batch 2060: accuracy=0.7224, loss=0.5635
# 2069/2500 ━━━━━━━━━━━━━━━━━━━━ 48s 112ms/step - accuracy: 0.6918 - loss: 0.6106Batch 2070: accuracy=0.7225, loss=0.5635
# 2079/2500 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.6919 - loss: 0.6103Batch 2080: accuracy=0.7226, loss=0.5634
# 2089/2500 ━━━━━━━━━━━━━━━━━━━━ 45s 112ms/step - accuracy: 0.6921 - loss: 0.6101Batch 2090: accuracy=0.7225, loss=0.5635
# 2099/2500 ━━━━━━━━━━━━━━━━━━━━ 44s 112ms/step - accuracy: 0.6922 - loss: 0.6099Batch 2100: accuracy=0.7225, loss=0.5634
# 2109/2500 ━━━━━━━━━━━━━━━━━━━━ 43s 112ms/step - accuracy: 0.6924 - loss: 0.6097Batch 2110: accuracy=0.7226, loss=0.5632
# 2119/2500 ━━━━━━━━━━━━━━━━━━━━ 42s 112ms/step - accuracy: 0.6925 - loss: 0.6094Batch 2120: accuracy=0.7227, loss=0.5631
# 2129/2500 ━━━━━━━━━━━━━━━━━━━━ 41s 112ms/step - accuracy: 0.6927 - loss: 0.6092Batch 2130: accuracy=0.7227, loss=0.5632
# 2139/2500 ━━━━━━━━━━━━━━━━━━━━ 40s 112ms/step - accuracy: 0.6928 - loss: 0.6090Batch 2140: accuracy=0.7226, loss=0.5633
# 2149/2500 ━━━━━━━━━━━━━━━━━━━━ 39s 112ms/step - accuracy: 0.6929 - loss: 0.6088Batch 2150: accuracy=0.7228, loss=0.5629
# 2159/2500 ━━━━━━━━━━━━━━━━━━━━ 38s 112ms/step - accuracy: 0.6931 - loss: 0.6086Batch 2160: accuracy=0.7228, loss=0.5628
# 2169/2500 ━━━━━━━━━━━━━━━━━━━━ 36s 112ms/step - accuracy: 0.6932 - loss: 0.6084Batch 2170: accuracy=0.7228, loss=0.5627
# 2179/2500 ━━━━━━━━━━━━━━━━━━━━ 35s 112ms/step - accuracy: 0.6934 - loss: 0.6082Batch 2180: accuracy=0.7229, loss=0.5625
# 2189/2500 ━━━━━━━━━━━━━━━━━━━━ 34s 112ms/step - accuracy: 0.6935 - loss: 0.6080Batch 2190: accuracy=0.7228, loss=0.5625
# 2199/2500 ━━━━━━━━━━━━━━━━━━━━ 33s 112ms/step - accuracy: 0.6936 - loss: 0.6078Batch 2200: accuracy=0.7230, loss=0.5623
# 2209/2500 ━━━━━━━━━━━━━━━━━━━━ 32s 112ms/step - accuracy: 0.6938 - loss: 0.6075Batch 2210: accuracy=0.7232, loss=0.5619
# 2219/2500 ━━━━━━━━━━━━━━━━━━━━ 31s 112ms/step - accuracy: 0.6939 - loss: 0.6073Batch 2220: accuracy=0.7232, loss=0.5619
# 2229/2500 ━━━━━━━━━━━━━━━━━━━━ 30s 112ms/step - accuracy: 0.6940 - loss: 0.6071Batch 2230: accuracy=0.7232, loss=0.5619
# 2239/2500 ━━━━━━━━━━━━━━━━━━━━ 29s 112ms/step - accuracy: 0.6942 - loss: 0.6069Batch 2240: accuracy=0.7232, loss=0.5619
# 2249/2500 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - accuracy: 0.6943 - loss: 0.6067Batch 2250: accuracy=0.7232, loss=0.5617
# 2259/2500 ━━━━━━━━━━━━━━━━━━━━ 26s 112ms/step - accuracy: 0.6944 - loss: 0.6065Batch 2260: accuracy=0.7234, loss=0.5614
# 2269/2500 ━━━━━━━━━━━━━━━━━━━━ 25s 112ms/step - accuracy: 0.6945 - loss: 0.6063Batch 2270: accuracy=0.7234, loss=0.5614
# 2279/2500 ━━━━━━━━━━━━━━━━━━━━ 24s 112ms/step - accuracy: 0.6947 - loss: 0.6061Batch 2280: accuracy=0.7234, loss=0.5614
# 2289/2500 ━━━━━━━━━━━━━━━━━━━━ 23s 112ms/step - accuracy: 0.6948 - loss: 0.6059Batch 2290: accuracy=0.7234, loss=0.5612
# 2299/2500 ━━━━━━━━━━━━━━━━━━━━ 22s 112ms/step - accuracy: 0.6949 - loss: 0.6057Batch 2300: accuracy=0.7234, loss=0.5610
# 2309/2500 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - accuracy: 0.6950 - loss: 0.6056Batch 2310: accuracy=0.7235, loss=0.5609
# 2319/2500 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - accuracy: 0.6952 - loss: 0.6054Batch 2320: accuracy=0.7236, loss=0.5608
# 2329/2500 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - accuracy: 0.6953 - loss: 0.6052Batch 2330: accuracy=0.7238, loss=0.5604
# 2339/2500 ━━━━━━━━━━━━━━━━━━━━ 17s 112ms/step - accuracy: 0.6954 - loss: 0.6050Batch 2340: accuracy=0.7238, loss=0.5605
# 2349/2500 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.6955 - loss: 0.6048Batch 2350: accuracy=0.7240, loss=0.5603
# 2359/2500 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - accuracy: 0.6957 - loss: 0.6046Batch 2360: accuracy=0.7240, loss=0.5604
# 2369/2500 ━━━━━━━━━━━━━━━━━━━━ 14s 112ms/step - accuracy: 0.6958 - loss: 0.6044Batch 2370: accuracy=0.7240, loss=0.5602
# 2379/2500 ━━━━━━━━━━━━━━━━━━━━ 13s 112ms/step - accuracy: 0.6959 - loss: 0.6042Batch 2380: accuracy=0.7241, loss=0.5601
# 2389/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.6960 - loss: 0.6040Batch 2390: accuracy=0.7242, loss=0.5601
# 2399/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 112ms/step - accuracy: 0.6961 - loss: 0.6039Batch 2400: accuracy=0.7242, loss=0.5599
# 2409/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - accuracy: 0.6962 - loss: 0.6037Batch 2410: accuracy=0.7243, loss=0.5597
# 2419/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 0.6964 - loss: 0.6035Batch 2420: accuracy=0.7243, loss=0.5598
# 2429/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - accuracy: 0.6965 - loss: 0.6033Batch 2430: accuracy=0.7243, loss=0.5596
# 2439/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.6966 - loss: 0.6031Batch 2440: accuracy=0.7242, loss=0.5598
# 2449/2500 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.6967 - loss: 0.6030Batch 2450: accuracy=0.7243, loss=0.5599
# 2459/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.6968 - loss: 0.6028Batch 2460: accuracy=0.7244, loss=0.5598
# 2469/2500 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.6969 - loss: 0.6026Batch 2470: accuracy=0.7246, loss=0.5595
# 2479/2500 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.6970 - loss: 0.6024Batch 2480: accuracy=0.7245, loss=0.5596
# 2489/2500 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.6971 - loss: 0.6023Batch 2490: accuracy=0.7246, loss=0.5593
# 2499/2500 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6973 - loss: 0.6021Batch 2500: accuracy=0.7246, loss=0.5593
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6973 - loss: 0.6021
# Epoch 1: val_loss improved from inf to 0.49415, saving model to best_model.keras
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 373s 143ms/step - accuracy: 0.6973 - loss: 0.6021 - val_accuracy: 0.7667 - val_loss: 0.4941 - learning_rate: 0.0010
# Epoch 2/10
#    9/2500 ━━━━━━━━━━━━━━━━━━━━ 4:41 113ms/step - accuracy: 0.7423 - loss: 0.5377Batch 10: accuracy=0.7375, loss=0.5797
#   19/2500 ━━━━━━━━━━━━━━━━━━━━ 4:40 113ms/step - accuracy: 0.7410 - loss: 0.5504Batch 20: accuracy=0.7406, loss=0.5485
#   29/2500 ━━━━━━━━━━━━━━━━━━━━ 4:39 113ms/step - accuracy: 0.7409 - loss: 0.5494Batch 30: accuracy=0.7375, loss=0.5536
#   39/2500 ━━━━━━━━━━━━━━━━━━━━ 4:38 113ms/step - accuracy: 0.7407 - loss: 0.5491Batch 40: accuracy=0.7375, loss=0.5545
#   49/2500 ━━━━━━━━━━━━━━━━━━━━ 4:37 113ms/step - accuracy: 0.7396 - loss: 0.5502Batch 50: accuracy=0.7331, loss=0.5523
#   59/2500 ━━━━━━━━━━━━━━━━━━━━ 4:36 113ms/step - accuracy: 0.7388 - loss: 0.5493Batch 60: accuracy=0.7339, loss=0.5458
#   69/2500 ━━━━━━━━━━━━━━━━━━━━ 4:35 113ms/step - accuracy: 0.7381 - loss: 0.5486Batch 70: accuracy=0.7344, loss=0.5416
#   79/2500 ━━━━━━━━━━━━━━━━━━━━ 4:34 113ms/step - accuracy: 0.7377 - loss: 0.5477Batch 80: accuracy=0.7371, loss=0.5412
#   89/2500 ━━━━━━━━━━━━━━━━━━━━ 4:33 113ms/step - accuracy: 0.7376 - loss: 0.5467Batch 90: accuracy=0.7358, loss=0.5363
#   99/2500 ━━━━━━━━━━━━━━━━━━━━ 4:31 113ms/step - accuracy: 0.7375 - loss: 0.5457Batch 100: accuracy=0.7381, loss=0.5349
#  109/2500 ━━━━━━━━━━━━━━━━━━━━ 4:30 113ms/step - accuracy: 0.7377 - loss: 0.5444Batch 110: accuracy=0.7403, loss=0.5310
#  119/2500 ━━━━━━━━━━━━━━━━━━━━ 4:29 113ms/step - accuracy: 0.7379 - loss: 0.5433Batch 120: accuracy=0.7404, loss=0.5307
#  129/2500 ━━━━━━━━━━━━━━━━━━━━ 4:28 113ms/step - accuracy: 0.7381 - loss: 0.5424Batch 130: accuracy=0.7401, loss=0.5300
#  139/2500 ━━━━━━━━━━━━━━━━━━━━ 4:27 113ms/step - accuracy: 0.7382 - loss: 0.5416Batch 140: accuracy=0.7373, loss=0.5341
#  149/2500 ━━━━━━━━━━━━━━━━━━━━ 4:26 113ms/step - accuracy: 0.7380 - loss: 0.5413Batch 150: accuracy=0.7346, loss=0.5398
#  159/2500 ━━━━━━━━━━━━━━━━━━━━ 4:25 114ms/step - accuracy: 0.7376 - loss: 0.5413Batch 160: accuracy=0.7324, loss=0.5410
#  169/2500 ━━━━━━━━━━━━━━━━━━━━ 4:24 114ms/step - accuracy: 0.7374 - loss: 0.5412Batch 170: accuracy=0.7347, loss=0.5388
#  179/2500 ━━━━━━━━━━━━━━━━━━━━ 4:23 114ms/step - accuracy: 0.7373 - loss: 0.5410Batch 180: accuracy=0.7363, loss=0.5371
#  189/2500 ━━━━━━━━━━━━━━━━━━━━ 4:22 114ms/step - accuracy: 0.7373 - loss: 0.5407Batch 190: accuracy=0.7387, loss=0.5335
#  199/2500 ━━━━━━━━━━━━━━━━━━━━ 4:21 114ms/step - accuracy: 0.7374 - loss: 0.5404Batch 200: accuracy=0.7373, loss=0.5345
#  209/2500 ━━━━━━━━━━━━━━━━━━━━ 4:20 114ms/step - accuracy: 0.7373 - loss: 0.5401Batch 210: accuracy=0.7372, loss=0.5350
#  219/2500 ━━━━━━━━━━━━━━━━━━━━ 4:19 114ms/step - accuracy: 0.7373 - loss: 0.5400Batch 220: accuracy=0.7354, loss=0.5382
#  229/2500 ━━━━━━━━━━━━━━━━━━━━ 4:18 114ms/step - accuracy: 0.7372 - loss: 0.5399Batch 230: accuracy=0.7333, loss=0.5399
#  239/2500 ━━━━━━━━━━━━━━━━━━━━ 4:18 114ms/step - accuracy: 0.7371 - loss: 0.5399Batch 240: accuracy=0.7345, loss=0.5395
#  249/2500 ━━━━━━━━━━━━━━━━━━━━ 4:17 114ms/step - accuracy: 0.7369 - loss: 0.5399Batch 250: accuracy=0.7334, loss=0.5416
#  259/2500 ━━━━━━━━━━━━━━━━━━━━ 4:16 114ms/step - accuracy: 0.7368 - loss: 0.5399Batch 260: accuracy=0.7350, loss=0.5394
#  269/2500 ━━━━━━━━━━━━━━━━━━━━ 4:14 114ms/step - accuracy: 0.7367 - loss: 0.5399Batch 270: accuracy=0.7346, loss=0.5395
#  279/2500 ━━━━━━━━━━━━━━━━━━━━ 4:13 114ms/step - accuracy: 0.7366 - loss: 0.5399Batch 280: accuracy=0.7328, loss=0.5422
#  289/2500 ━━━━━━━━━━━━━━━━━━━━ 4:12 114ms/step - accuracy: 0.7365 - loss: 0.5400Batch 290: accuracy=0.7333, loss=0.5418
#  299/2500 ━━━━━━━━━━━━━━━━━━━━ 4:11 114ms/step - accuracy: 0.7364 - loss: 0.5401Batch 300: accuracy=0.7318, loss=0.5432
#  309/2500 ━━━━━━━━━━━━━━━━━━━━ 4:10 114ms/step - accuracy: 0.7362 - loss: 0.5402Batch 310: accuracy=0.7329, loss=0.5429
#  319/2500 ━━━━━━━━━━━━━━━━━━━━ 4:09 114ms/step - accuracy: 0.7361 - loss: 0.5403Batch 320: accuracy=0.7325, loss=0.5444
#  329/2500 ━━━━━━━━━━━━━━━━━━━━ 4:08 114ms/step - accuracy: 0.7360 - loss: 0.5404Batch 330: accuracy=0.7322, loss=0.5442
#  339/2500 ━━━━━━━━━━━━━━━━━━━━ 4:07 114ms/step - accuracy: 0.7359 - loss: 0.5405Batch 340: accuracy=0.7323, loss=0.5425
#  349/2500 ━━━━━━━━━━━━━━━━━━━━ 4:06 114ms/step - accuracy: 0.7358 - loss: 0.5406Batch 350: accuracy=0.7331, loss=0.5423
#  359/2500 ━━━━━━━━━━━━━━━━━━━━ 4:05 114ms/step - accuracy: 0.7358 - loss: 0.5406Batch 360: accuracy=0.7334, loss=0.5423
#  369/2500 ━━━━━━━━━━━━━━━━━━━━ 4:03 114ms/step - accuracy: 0.7357 - loss: 0.5406Batch 370: accuracy=0.7340, loss=0.5410
#  379/2500 ━━━━━━━━━━━━━━━━━━━━ 4:02 114ms/step - accuracy: 0.7356 - loss: 0.5407Batch 380: accuracy=0.7336, loss=0.5420
#  389/2500 ━━━━━━━━━━━━━━━━━━━━ 4:01 115ms/step - accuracy: 0.7356 - loss: 0.5407Batch 390: accuracy=0.7336, loss=0.5421
#  399/2500 ━━━━━━━━━━━━━━━━━━━━ 4:00 114ms/step - accuracy: 0.7355 - loss: 0.5407Batch 400: accuracy=0.7343, loss=0.5423
#  409/2500 ━━━━━━━━━━━━━━━━━━━━ 3:59 114ms/step - accuracy: 0.7355 - loss: 0.5408Batch 410: accuracy=0.7338, loss=0.5429
#  419/2500 ━━━━━━━━━━━━━━━━━━━━ 3:58 114ms/step - accuracy: 0.7355 - loss: 0.5408Batch 420: accuracy=0.7332, loss=0.5441
#  429/2500 ━━━━━━━━━━━━━━━━━━━━ 3:57 114ms/step - accuracy: 0.7354 - loss: 0.5409Batch 430: accuracy=0.7343, loss=0.5437
#  439/2500 ━━━━━━━━━━━━━━━━━━━━ 3:55 114ms/step - accuracy: 0.7354 - loss: 0.5410Batch 440: accuracy=0.7346, loss=0.5440
#  449/2500 ━━━━━━━━━━━━━━━━━━━━ 3:54 114ms/step - accuracy: 0.7354 - loss: 0.5411Batch 450: accuracy=0.7340, loss=0.5443
#  459/2500 ━━━━━━━━━━━━━━━━━━━━ 3:53 114ms/step - accuracy: 0.7354 - loss: 0.5411Batch 460: accuracy=0.7343, loss=0.5452
#  469/2500 ━━━━━━━━━━━━━━━━━━━━ 3:52 114ms/step - accuracy: 0.7353 - loss: 0.5412Batch 470: accuracy=0.7338, loss=0.5458
#  479/2500 ━━━━━━━━━━━━━━━━━━━━ 3:51 114ms/step - accuracy: 0.7353 - loss: 0.5413Batch 480: accuracy=0.7340, loss=0.5453
#  489/2500 ━━━━━━━━━━━━━━━━━━━━ 3:50 114ms/step - accuracy: 0.7353 - loss: 0.5414Batch 490: accuracy=0.7343, loss=0.5446
#  499/2500 ━━━━━━━━━━━━━━━━━━━━ 3:48 114ms/step - accuracy: 0.7353 - loss: 0.5414Batch 500: accuracy=0.7348, loss=0.5432
#  509/2500 ━━━━━━━━━━━━━━━━━━━━ 3:47 114ms/step - accuracy: 0.7353 - loss: 0.5415Batch 510: accuracy=0.7353, loss=0.5425
#  519/2500 ━━━━━━━━━━━━━━━━━━━━ 3:46 114ms/step - accuracy: 0.7352 - loss: 0.5415Batch 520: accuracy=0.7346, loss=0.5435
#  529/2500 ━━━━━━━━━━━━━━━━━━━━ 3:45 114ms/step - accuracy: 0.7352 - loss: 0.5415Batch 530: accuracy=0.7350, loss=0.5429
#  539/2500 ━━━━━━━━━━━━━━━━━━━━ 3:44 114ms/step - accuracy: 0.7352 - loss: 0.5416Batch 540: accuracy=0.7349, loss=0.5435
#  549/2500 ━━━━━━━━━━━━━━━━━━━━ 3:43 114ms/step - accuracy: 0.7352 - loss: 0.5416Batch 550: accuracy=0.7354, loss=0.5432
#  559/2500 ━━━━━━━━━━━━━━━━━━━━ 3:41 114ms/step - accuracy: 0.7352 - loss: 0.5416Batch 560: accuracy=0.7347, loss=0.5446
#  569/2500 ━━━━━━━━━━━━━━━━━━━━ 3:40 114ms/step - accuracy: 0.7352 - loss: 0.5417Batch 570: accuracy=0.7350, loss=0.5441
#  579/2500 ━━━━━━━━━━━━━━━━━━━━ 3:39 114ms/step - accuracy: 0.7352 - loss: 0.5417Batch 580: accuracy=0.7352, loss=0.5433
#  589/2500 ━━━━━━━━━━━━━━━━━━━━ 3:38 114ms/step - accuracy: 0.7352 - loss: 0.5418Batch 590: accuracy=0.7351, loss=0.5439
#  599/2500 ━━━━━━━━━━━━━━━━━━━━ 3:37 114ms/step - accuracy: 0.7352 - loss: 0.5418Batch 600: accuracy=0.7354, loss=0.5435
#  609/2500 ━━━━━━━━━━━━━━━━━━━━ 3:36 114ms/step - accuracy: 0.7352 - loss: 0.5418Batch 610: accuracy=0.7355, loss=0.5432
#  619/2500 ━━━━━━━━━━━━━━━━━━━━ 3:34 114ms/step - accuracy: 0.7352 - loss: 0.5418Batch 620: accuracy=0.7355, loss=0.5428
#  629/2500 ━━━━━━━━━━━━━━━━━━━━ 3:33 114ms/step - accuracy: 0.7352 - loss: 0.5418Batch 630: accuracy=0.7355, loss=0.5426
#  639/2500 ━━━━━━━━━━━━━━━━━━━━ 3:32 114ms/step - accuracy: 0.7352 - loss: 0.5419Batch 640: accuracy=0.7349, loss=0.5438
#  649/2500 ━━━━━━━━━━━━━━━━━━━━ 3:31 114ms/step - accuracy: 0.7352 - loss: 0.5419Batch 650: accuracy=0.7346, loss=0.5441
#  659/2500 ━━━━━━━━━━━━━━━━━━━━ 3:30 114ms/step - accuracy: 0.7352 - loss: 0.5419Batch 660: accuracy=0.7347, loss=0.5442
#  669/2500 ━━━━━━━━━━━━━━━━━━━━ 3:29 114ms/step - accuracy: 0.7352 - loss: 0.5420Batch 670: accuracy=0.7353, loss=0.5435
#  679/2500 ━━━━━━━━━━━━━━━━━━━━ 3:27 114ms/step - accuracy: 0.7352 - loss: 0.5420Batch 680: accuracy=0.7347, loss=0.5436
#  689/2500 ━━━━━━━━━━━━━━━━━━━━ 3:26 114ms/step - accuracy: 0.7352 - loss: 0.5420Batch 690: accuracy=0.7343, loss=0.5441
#  699/2500 ━━━━━━━━━━━━━━━━━━━━ 3:25 114ms/step - accuracy: 0.7352 - loss: 0.5420Batch 700: accuracy=0.7345, loss=0.5435
#  709/2500 ━━━━━━━━━━━━━━━━━━━━ 3:24 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 710: accuracy=0.7348, loss=0.5431
#  719/2500 ━━━━━━━━━━━━━━━━━━━━ 3:23 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 720: accuracy=0.7353, loss=0.5424
#  729/2500 ━━━━━━━━━━━━━━━━━━━━ 3:22 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 730: accuracy=0.7347, loss=0.5426
#  739/2500 ━━━━━━━━━━━━━━━━━━━━ 3:20 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 740: accuracy=0.7351, loss=0.5419
#  749/2500 ━━━━━━━━━━━━━━━━━━━━ 3:19 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 750: accuracy=0.7353, loss=0.5422
#  759/2500 ━━━━━━━━━━━━━━━━━━━━ 3:18 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 760: accuracy=0.7354, loss=0.5426
#  769/2500 ━━━━━━━━━━━━━━━━━━━━ 3:17 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 770: accuracy=0.7353, loss=0.5424
#  779/2500 ━━━━━━━━━━━━━━━━━━━━ 3:16 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 780: accuracy=0.7355, loss=0.5421
#  789/2500 ━━━━━━━━━━━━━━━━━━━━ 3:15 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 790: accuracy=0.7352, loss=0.5423
#  799/2500 ━━━━━━━━━━━━━━━━━━━━ 3:14 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 800: accuracy=0.7353, loss=0.5421
#  809/2500 ━━━━━━━━━━━━━━━━━━━━ 3:12 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 810: accuracy=0.7351, loss=0.5422
#  819/2500 ━━━━━━━━━━━━━━━━━━━━ 3:11 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 820: accuracy=0.7350, loss=0.5421
#  829/2500 ━━━━━━━━━━━━━━━━━━━━ 3:10 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 830: accuracy=0.7352, loss=0.5421
#  839/2500 ━━━━━━━━━━━━━━━━━━━━ 3:09 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 840: accuracy=0.7351, loss=0.5417
#  849/2500 ━━━━━━━━━━━━━━━━━━━━ 3:08 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 850: accuracy=0.7351, loss=0.5415
#  859/2500 ━━━━━━━━━━━━━━━━━━━━ 3:07 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 860: accuracy=0.7348, loss=0.5419
#  869/2500 ━━━━━━━━━━━━━━━━━━━━ 3:06 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 870: accuracy=0.7352, loss=0.5415
#  879/2500 ━━━━━━━━━━━━━━━━━━━━ 3:04 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 880: accuracy=0.7353, loss=0.5411
#  889/2500 ━━━━━━━━━━━━━━━━━━━━ 3:03 114ms/step - accuracy: 0.7352 - loss: 0.5421Batch 890: accuracy=0.7353, loss=0.5410
#  899/2500 ━━━━━━━━━━━━━━━━━━━━ 3:02 114ms/step - accuracy: 0.7352 - loss: 0.5420Batch 900: accuracy=0.7350, loss=0.5408
#  909/2500 ━━━━━━━━━━━━━━━━━━━━ 3:01 114ms/step - accuracy: 0.7352 - loss: 0.5420Batch 910: accuracy=0.7350, loss=0.5406
#  919/2500 ━━━━━━━━━━━━━━━━━━━━ 3:00 114ms/step - accuracy: 0.7352 - loss: 0.5420Batch 920: accuracy=0.7354, loss=0.5402
#  929/2500 ━━━━━━━━━━━━━━━━━━━━ 2:59 114ms/step - accuracy: 0.7352 - loss: 0.5420Batch 930: accuracy=0.7355, loss=0.5405
#  939/2500 ━━━━━━━━━━━━━━━━━━━━ 2:58 114ms/step - accuracy: 0.7352 - loss: 0.5420Batch 940: accuracy=0.7357, loss=0.5404
#  949/2500 ━━━━━━━━━━━━━━━━━━━━ 2:57 114ms/step - accuracy: 0.7352 - loss: 0.5420Batch 950: accuracy=0.7353, loss=0.5409
#  959/2500 ━━━━━━━━━━━━━━━━━━━━ 2:55 114ms/step - accuracy: 0.7352 - loss: 0.5420Batch 960: accuracy=0.7355, loss=0.5405
#  969/2500 ━━━━━━━━━━━━━━━━━━━━ 2:54 114ms/step - accuracy: 0.7352 - loss: 0.5419Batch 970: accuracy=0.7356, loss=0.5403
#  979/2500 ━━━━━━━━━━━━━━━━━━━━ 2:53 114ms/step - accuracy: 0.7352 - loss: 0.5419Batch 980: accuracy=0.7356, loss=0.5404
#  989/2500 ━━━━━━━━━━━━━━━━━━━━ 2:52 114ms/step - accuracy: 0.7352 - loss: 0.5419Batch 990: accuracy=0.7353, loss=0.5405
#  999/2500 ━━━━━━━━━━━━━━━━━━━━ 2:51 114ms/step - accuracy: 0.7352 - loss: 0.5419Batch 1000: accuracy=0.7355, loss=0.5403
# 1009/2500 ━━━━━━━━━━━━━━━━━━━━ 2:50 114ms/step - accuracy: 0.7352 - loss: 0.5419Batch 1010: accuracy=0.7354, loss=0.5402
# 1019/2500 ━━━━━━━━━━━━━━━━━━━━ 2:49 114ms/step - accuracy: 0.7352 - loss: 0.5419Batch 1020: accuracy=0.7357, loss=0.5398
# 1029/2500 ━━━━━━━━━━━━━━━━━━━━ 2:47 114ms/step - accuracy: 0.7352 - loss: 0.5418Batch 1030: accuracy=0.7358, loss=0.5395
# 1039/2500 ━━━━━━━━━━━━━━━━━━━━ 2:46 114ms/step - accuracy: 0.7352 - loss: 0.5418Batch 1040: accuracy=0.7357, loss=0.5402
# 1049/2500 ━━━━━━━━━━━━━━━━━━━━ 2:45 114ms/step - accuracy: 0.7352 - loss: 0.5418Batch 1050: accuracy=0.7356, loss=0.5400
# 1059/2500 ━━━━━━━━━━━━━━━━━━━━ 2:44 114ms/step - accuracy: 0.7352 - loss: 0.5418Batch 1060: accuracy=0.7361, loss=0.5397
# 1069/2500 ━━━━━━━━━━━━━━━━━━━━ 2:43 114ms/step - accuracy: 0.7352 - loss: 0.5418Batch 1070: accuracy=0.7360, loss=0.5398
# 1079/2500 ━━━━━━━━━━━━━━━━━━━━ 2:42 114ms/step - accuracy: 0.7352 - loss: 0.5417Batch 1080: accuracy=0.7359, loss=0.5398
# 1089/2500 ━━━━━━━━━━━━━━━━━━━━ 2:41 114ms/step - accuracy: 0.7352 - loss: 0.5417Batch 1090: accuracy=0.7360, loss=0.5396
# 1099/2500 ━━━━━━━━━━━━━━━━━━━━ 2:39 114ms/step - accuracy: 0.7353 - loss: 0.5417Batch 1100: accuracy=0.7363, loss=0.5394
# 1109/2500 ━━━━━━━━━━━━━━━━━━━━ 2:38 114ms/step - accuracy: 0.7353 - loss: 0.5417Batch 1110: accuracy=0.7366, loss=0.5395
# 1119/2500 ━━━━━━━━━━━━━━━━━━━━ 2:37 114ms/step - accuracy: 0.7353 - loss: 0.5417Batch 1120: accuracy=0.7368, loss=0.5392
# 1129/2500 ━━━━━━━━━━━━━━━━━━━━ 2:36 114ms/step - accuracy: 0.7353 - loss: 0.5416Batch 1130: accuracy=0.7366, loss=0.5396
# 1139/2500 ━━━━━━━━━━━━━━━━━━━━ 2:35 114ms/step - accuracy: 0.7353 - loss: 0.5416Batch 1140: accuracy=0.7368, loss=0.5394
# 1149/2500 ━━━━━━━━━━━━━━━━━━━━ 2:34 114ms/step - accuracy: 0.7353 - loss: 0.5416Batch 1150: accuracy=0.7368, loss=0.5393
# 1159/2500 ━━━━━━━━━━━━━━━━━━━━ 2:33 114ms/step - accuracy: 0.7353 - loss: 0.5416Batch 1160: accuracy=0.7370, loss=0.5391
# 1169/2500 ━━━━━━━━━━━━━━━━━━━━ 2:31 114ms/step - accuracy: 0.7353 - loss: 0.5416Batch 1170: accuracy=0.7371, loss=0.5387
# 1179/2500 ━━━━━━━━━━━━━━━━━━━━ 2:30 114ms/step - accuracy: 0.7354 - loss: 0.5415Batch 1180: accuracy=0.7377, loss=0.5380
# 1189/2500 ━━━━━━━━━━━━━━━━━━━━ 2:29 114ms/step - accuracy: 0.7354 - loss: 0.5415Batch 1190: accuracy=0.7378, loss=0.5381
# 1199/2500 ━━━━━━━━━━━━━━━━━━━━ 2:28 114ms/step - accuracy: 0.7354 - loss: 0.5415Batch 1200: accuracy=0.7376, loss=0.5383
# 1209/2500 ━━━━━━━━━━━━━━━━━━━━ 2:27 114ms/step - accuracy: 0.7354 - loss: 0.5415Batch 1210: accuracy=0.7376, loss=0.5379
# 1219/2500 ━━━━━━━━━━━━━━━━━━━━ 2:26 114ms/step - accuracy: 0.7354 - loss: 0.5414Batch 1220: accuracy=0.7376, loss=0.5380
# 1229/2500 ━━━━━━━━━━━━━━━━━━━━ 2:25 114ms/step - accuracy: 0.7355 - loss: 0.5414Batch 1230: accuracy=0.7376, loss=0.5378
# 1239/2500 ━━━━━━━━━━━━━━━━━━━━ 2:23 114ms/step - accuracy: 0.7355 - loss: 0.5414Batch 1240: accuracy=0.7378, loss=0.5378
# 1249/2500 ━━━━━━━━━━━━━━━━━━━━ 2:22 114ms/step - accuracy: 0.7355 - loss: 0.5413Batch 1250: accuracy=0.7377, loss=0.5381
# 1259/2500 ━━━━━━━━━━━━━━━━━━━━ 2:21 114ms/step - accuracy: 0.7355 - loss: 0.5413Batch 1260: accuracy=0.7381, loss=0.5377
# 1269/2500 ━━━━━━━━━━━━━━━━━━━━ 2:20 114ms/step - accuracy: 0.7355 - loss: 0.5413Batch 1270: accuracy=0.7383, loss=0.5373
# 1279/2500 ━━━━━━━━━━━━━━━━━━━━ 2:19 114ms/step - accuracy: 0.7356 - loss: 0.5413Batch 1280: accuracy=0.7380, loss=0.5379
# 1289/2500 ━━━━━━━━━━━━━━━━━━━━ 2:18 114ms/step - accuracy: 0.7356 - loss: 0.5412Batch 1290: accuracy=0.7382, loss=0.5378
# 1299/2500 ━━━━━━━━━━━━━━━━━━━━ 2:17 114ms/step - accuracy: 0.7356 - loss: 0.5412Batch 1300: accuracy=0.7380, loss=0.5387
# 1309/2500 ━━━━━━━━━━━━━━━━━━━━ 2:15 114ms/step - accuracy: 0.7356 - loss: 0.5412Batch 1310: accuracy=0.7379, loss=0.5387
# 1319/2500 ━━━━━━━━━━━━━━━━━━━━ 2:14 114ms/step - accuracy: 0.7356 - loss: 0.5412Batch 1320: accuracy=0.7379, loss=0.5386
# 1329/2500 ━━━━━━━━━━━━━━━━━━━━ 2:13 114ms/step - accuracy: 0.7356 - loss: 0.5411Batch 1330: accuracy=0.7381, loss=0.5384
# 1339/2500 ━━━━━━━━━━━━━━━━━━━━ 2:12 114ms/step - accuracy: 0.7357 - loss: 0.5411Batch 1340: accuracy=0.7379, loss=0.5389
# 1349/2500 ━━━━━━━━━━━━━━━━━━━━ 2:11 114ms/step - accuracy: 0.7357 - loss: 0.5411Batch 1350: accuracy=0.7379, loss=0.5394
# 1359/2500 ━━━━━━━━━━━━━━━━━━━━ 2:10 114ms/step - accuracy: 0.7357 - loss: 0.5411Batch 1360: accuracy=0.7379, loss=0.5396
# 1369/2500 ━━━━━━━━━━━━━━━━━━━━ 2:08 114ms/step - accuracy: 0.7357 - loss: 0.5411Batch 1370: accuracy=0.7382, loss=0.5392
# 1379/2500 ━━━━━━━━━━━━━━━━━━━━ 2:07 114ms/step - accuracy: 0.7357 - loss: 0.5411Batch 1380: accuracy=0.7384, loss=0.5390
# 1389/2500 ━━━━━━━━━━━━━━━━━━━━ 2:06 114ms/step - accuracy: 0.7358 - loss: 0.5411Batch 1390: accuracy=0.7383, loss=0.5394
# 1399/2500 ━━━━━━━━━━━━━━━━━━━━ 2:05 114ms/step - accuracy: 0.7358 - loss: 0.5410Batch 1400: accuracy=0.7385, loss=0.5392
# 1409/2500 ━━━━━━━━━━━━━━━━━━━━ 2:04 114ms/step - accuracy: 0.7358 - loss: 0.5410Batch 1410: accuracy=0.7386, loss=0.5390
# 1419/2500 ━━━━━━━━━━━━━━━━━━━━ 2:03 114ms/step - accuracy: 0.7358 - loss: 0.5410Batch 1420: accuracy=0.7388, loss=0.5388
# 1429/2500 ━━━━━━━━━━━━━━━━━━━━ 2:02 114ms/step - accuracy: 0.7358 - loss: 0.5410Batch 1430: accuracy=0.7389, loss=0.5386
# 1439/2500 ━━━━━━━━━━━━━━━━━━━━ 2:00 114ms/step - accuracy: 0.7359 - loss: 0.5410Batch 1440: accuracy=0.7390, loss=0.5387
# 1449/2500 ━━━━━━━━━━━━━━━━━━━━ 1:59 114ms/step - accuracy: 0.7359 - loss: 0.5410Batch 1450: accuracy=0.7389, loss=0.5388
# 1459/2500 ━━━━━━━━━━━━━━━━━━━━ 1:58 114ms/step - accuracy: 0.7359 - loss: 0.5410Batch 1460: accuracy=0.7390, loss=0.5385
# ...
# 1219/2500 ━━━━━━━━━━━━━━━━━━━━ 2:25 114ms/step - accuracy: 0.7502 - loss: 0.5133Batch 1220: accuracy=0.7518, loss=0.5134
# 1229/2500 ━━━━━━━━━━━━━━━━━━━━ 2:24 114ms/step - accuracy: 0.7502 - loss: 0.5133Batch 1230: accuracy=0.7515, loss=0.5140
# 1239/2500 ━━━━━━━━━━━━━━━━━━━━ 2:23 114ms/step - accuracy: 0.7502 - loss: 0.5133Batch 1240: accuracy=0.7514, loss=0.5141
# 1249/2500 ━━━━━━━━━━━━━━━━━━━━ 2:22 114ms/step - accuracy: 0.7502 - loss: 0.5133Batch 1250: accuracy=0.7516, loss=0.5141
# 1259/2500 ━━━━━━━━━━━━━━━━━━━━ 2:21 114ms/step - accuracy: 0.7502 - loss: 0.5133Batch 1260: accuracy=0.7516, loss=0.5140
# 1269/2500 ━━━━━━━━━━━━━━━━━━━━ 2:20 114ms/step - accuracy: 0.7503 - loss: 0.5133Batch 1270: accuracy=0.7517, loss=0.5138
# 1279/2500 ━━━━━━━━━━━━━━━━━━━━ 2:18 114ms/step - accuracy: 0.7503 - loss: 0.5133Batch 1280: accuracy=0.7517, loss=0.5138
# 1289/2500 ━━━━━━━━━━━━━━━━━━━━ 2:17 114ms/step - accuracy: 0.7503 - loss: 0.5133Batch 1290: accuracy=0.7519, loss=0.5137
# 1299/2500 ━━━━━━━━━━━━━━━━━━━━ 2:16 114ms/step - accuracy: 0.7503 - loss: 0.5133Batch 1300: accuracy=0.7519, loss=0.5141
# 1309/2500 ━━━━━━━━━━━━━━━━━━━━ 2:15 114ms/step - accuracy: 0.7503 - loss: 0.5133Batch 1310: accuracy=0.7521, loss=0.5139
# 1319/2500 ━━━━━━━━━━━━━━━━━━━━ 2:14 114ms/step - accuracy: 0.7503 - loss: 0.5133Batch 1320: accuracy=0.7520, loss=0.5141
# 1329/2500 ━━━━━━━━━━━━━━━━━━━━ 2:13 114ms/step - accuracy: 0.7503 - loss: 0.5133Batch 1330: accuracy=0.7520, loss=0.5139
# 1339/2500 ━━━━━━━━━━━━━━━━━━━━ 2:12 114ms/step - accuracy: 0.7503 - loss: 0.5133Batch 1340: accuracy=0.7517, loss=0.5139
# 1349/2500 ━━━━━━━━━━━━━━━━━━━━ 2:10 114ms/step - accuracy: 0.7504 - loss: 0.5133Batch 1350: accuracy=0.7519, loss=0.5138
# 1359/2500 ━━━━━━━━━━━━━━━━━━━━ 2:09 114ms/step - accuracy: 0.7504 - loss: 0.5133Batch 1360: accuracy=0.7519, loss=0.5140
# 1369/2500 ━━━━━━━━━━━━━━━━━━━━ 2:08 114ms/step - accuracy: 0.7504 - loss: 0.5133Batch 1370: accuracy=0.7521, loss=0.5135
# 1379/2500 ━━━━━━━━━━━━━━━━━━━━ 2:07 114ms/step - accuracy: 0.7504 - loss: 0.5133Batch 1380: accuracy=0.7516, loss=0.5140
# 1389/2500 ━━━━━━━━━━━━━━━━━━━━ 2:06 114ms/step - accuracy: 0.7504 - loss: 0.5133Batch 1390: accuracy=0.7517, loss=0.5137
# 1399/2500 ━━━━━━━━━━━━━━━━━━━━ 2:05 114ms/step - accuracy: 0.7504 - loss: 0.5133Batch 1400: accuracy=0.7517, loss=0.5134
# 1409/2500 ━━━━━━━━━━━━━━━━━━━━ 2:04 114ms/step - accuracy: 0.7504 - loss: 0.5133Batch 1410: accuracy=0.7518, loss=0.5134
# 1419/2500 ━━━━━━━━━━━━━━━━━━━━ 2:02 114ms/step - accuracy: 0.7504 - loss: 0.5133Batch 1420: accuracy=0.7518, loss=0.5134
# 1429/2500 ━━━━━━━━━━━━━━━━━━━━ 2:01 114ms/step - accuracy: 0.7504 - loss: 0.5133Batch 1430: accuracy=0.7519, loss=0.5132
# 1439/2500 ━━━━━━━━━━━━━━━━━━━━ 2:00 114ms/step - accuracy: 0.7504 - loss: 0.5133Batch 1440: accuracy=0.7517, loss=0.5135
# 1449/2500 ━━━━━━━━━━━━━━━━━━━━ 1:59 114ms/step - accuracy: 0.7505 - loss: 0.5133Batch 1450: accuracy=0.7513, loss=0.5139
# 1459/2500 ━━━━━━━━━━━━━━━━━━━━ 1:58 114ms/step - accuracy: 0.7505 - loss: 0.5133Batch 1460: accuracy=0.7513, loss=0.5138
# 1469/2500 ━━━━━━━━━━━━━━━━━━━━ 1:57 114ms/step - accuracy: 0.7505 - loss: 0.5133Batch 1470: accuracy=0.7514, loss=0.5138
# 1479/2500 ━━━━━━━━━━━━━━━━━━━━ 1:56 114ms/step - accuracy: 0.7505 - loss: 0.5133Batch 1480: accuracy=0.7516, loss=0.5136
# 1489/2500 ━━━━━━━━━━━━━━━━━━━━ 1:54 114ms/step - accuracy: 0.7505 - loss: 0.5133Batch 1490: accuracy=0.7517, loss=0.5136
# 1499/2500 ━━━━━━━━━━━━━━━━━━━━ 1:53 114ms/step - accuracy: 0.7505 - loss: 0.5133Batch 1500: accuracy=0.7515, loss=0.5140
# 1509/2500 ━━━━━━━━━━━━━━━━━━━━ 1:52 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1510: accuracy=0.7515, loss=0.5140
# 1519/2500 ━━━━━━━━━━━━━━━━━━━━ 1:51 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1520: accuracy=0.7514, loss=0.5141
# 1529/2500 ━━━━━━━━━━━━━━━━━━━━ 1:50 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1530: accuracy=0.7513, loss=0.5141
# 1539/2500 ━━━━━━━━━━━━━━━━━━━━ 1:49 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1540: accuracy=0.7513, loss=0.5144
# 1549/2500 ━━━━━━━━━━━━━━━━━━━━ 1:48 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1550: accuracy=0.7513, loss=0.5145
# 1559/2500 ━━━━━━━━━━━━━━━━━━━━ 1:46 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1560: accuracy=0.7513, loss=0.5146
# 1569/2500 ━━━━━━━━━━━━━━━━━━━━ 1:45 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1570: accuracy=0.7513, loss=0.5147
# 1579/2500 ━━━━━━━━━━━━━━━━━━━━ 1:44 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1580: accuracy=0.7513, loss=0.5146
# 1589/2500 ━━━━━━━━━━━━━━━━━━━━ 1:43 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1590: accuracy=0.7512, loss=0.5147
# 1599/2500 ━━━━━━━━━━━━━━━━━━━━ 1:42 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1600: accuracy=0.7512, loss=0.5147
# 1609/2500 ━━━━━━━━━━━━━━━━━━━━ 1:41 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1610: accuracy=0.7512, loss=0.5146
# 1619/2500 ━━━━━━━━━━━━━━━━━━━━ 1:40 114ms/step - accuracy: 0.7505 - loss: 0.5134Batch 1620: accuracy=0.7512, loss=0.5147
# 1629/2500 ━━━━━━━━━━━━━━━━━━━━ 1:38 114ms/step - accuracy: 0.7506 - loss: 0.5134Batch 1630: accuracy=0.7510, loss=0.5149
# 1639/2500 ━━━━━━━━━━━━━━━━━━━━ 1:37 114ms/step - accuracy: 0.7506 - loss: 0.5134Batch 1640: accuracy=0.7510, loss=0.5149
# 1649/2500 ━━━━━━━━━━━━━━━━━━━━ 1:36 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1650: accuracy=0.7510, loss=0.5149
# 1659/2500 ━━━━━━━━━━━━━━━━━━━━ 1:35 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1660: accuracy=0.7513, loss=0.5145
# 1669/2500 ━━━━━━━━━━━━━━━━━━━━ 1:34 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1670: accuracy=0.7514, loss=0.5146
# 1679/2500 ━━━━━━━━━━━━━━━━━━━━ 1:33 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1680: accuracy=0.7514, loss=0.5146
# 1689/2500 ━━━━━━━━━━━━━━━━━━━━ 1:32 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1690: accuracy=0.7515, loss=0.5144
# 1699/2500 ━━━━━━━━━━━━━━━━━━━━ 1:30 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1700: accuracy=0.7516, loss=0.5145
# 1709/2500 ━━━━━━━━━━━━━━━━━━━━ 1:29 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1710: accuracy=0.7516, loss=0.5144
# 1719/2500 ━━━━━━━━━━━━━━━━━━━━ 1:28 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1720: accuracy=0.7519, loss=0.5142
# 1729/2500 ━━━━━━━━━━━━━━━━━━━━ 1:27 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1730: accuracy=0.7516, loss=0.5143
# 1739/2500 ━━━━━━━━━━━━━━━━━━━━ 1:26 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1740: accuracy=0.7517, loss=0.5143
# 1749/2500 ━━━━━━━━━━━━━━━━━━━━ 1:25 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1750: accuracy=0.7516, loss=0.5143
# 1759/2500 ━━━━━━━━━━━━━━━━━━━━ 1:24 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1760: accuracy=0.7515, loss=0.5145
# 1769/2500 ━━━━━━━━━━━━━━━━━━━━ 1:23 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1770: accuracy=0.7516, loss=0.5144
# 1779/2500 ━━━━━━━━━━━━━━━━━━━━ 1:21 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1780: accuracy=0.7518, loss=0.5144
# 1789/2500 ━━━━━━━━━━━━━━━━━━━━ 1:20 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1790: accuracy=0.7516, loss=0.5144
# 1799/2500 ━━━━━━━━━━━━━━━━━━━━ 1:19 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1800: accuracy=0.7515, loss=0.5147
# 1809/2500 ━━━━━━━━━━━━━━━━━━━━ 1:18 114ms/step - accuracy: 0.7506 - loss: 0.5135Batch 1810: accuracy=0.7514, loss=0.5148
# 1819/2500 ━━━━━━━━━━━━━━━━━━━━ 1:17 114ms/step - accuracy: 0.7506 - loss: 0.5136Batch 1820: accuracy=0.7514, loss=0.5147
# 1829/2500 ━━━━━━━━━━━━━━━━━━━━ 1:16 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1830: accuracy=0.7513, loss=0.5148
# 1839/2500 ━━━━━━━━━━━━━━━━━━━━ 1:15 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1840: accuracy=0.7512, loss=0.5149
# 1849/2500 ━━━━━━━━━━━━━━━━━━━━ 1:13 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1850: accuracy=0.7512, loss=0.5148
# 1859/2500 ━━━━━━━━━━━━━━━━━━━━ 1:12 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1860: accuracy=0.7514, loss=0.5146
# 1869/2500 ━━━━━━━━━━━━━━━━━━━━ 1:11 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1870: accuracy=0.7515, loss=0.5147
# 1879/2500 ━━━━━━━━━━━━━━━━━━━━ 1:10 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1880: accuracy=0.7515, loss=0.5146
# 1889/2500 ━━━━━━━━━━━━━━━━━━━━ 1:09 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1890: accuracy=0.7516, loss=0.5146
# 1899/2500 ━━━━━━━━━━━━━━━━━━━━ 1:08 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1900: accuracy=0.7516, loss=0.5147
# 1909/2500 ━━━━━━━━━━━━━━━━━━━━ 1:07 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1910: accuracy=0.7517, loss=0.5146
# 1919/2500 ━━━━━━━━━━━━━━━━━━━━ 1:05 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1920: accuracy=0.7518, loss=0.5145
# 1929/2500 ━━━━━━━━━━━━━━━━━━━━ 1:04 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1930: accuracy=0.7516, loss=0.5147
# 1939/2500 ━━━━━━━━━━━━━━━━━━━━ 1:03 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1940: accuracy=0.7515, loss=0.5147
# 1949/2500 ━━━━━━━━━━━━━━━━━━━━ 1:02 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1950: accuracy=0.7516, loss=0.5146
# 1959/2500 ━━━━━━━━━━━━━━━━━━━━ 1:01 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1960: accuracy=0.7517, loss=0.5143
# 1969/2500 ━━━━━━━━━━━━━━━━━━━━ 1:00 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1970: accuracy=0.7518, loss=0.5143
# 1979/2500 ━━━━━━━━━━━━━━━━━━━━ 59s 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1980: accuracy=0.7517, loss=0.5143
# 1989/2500 ━━━━━━━━━━━━━━━━━━━━ 58s 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 1990: accuracy=0.7518, loss=0.5144
# 1999/2500 ━━━━━━━━━━━━━━━━━━━━ 56s 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 2000: accuracy=0.7517, loss=0.5144
# 2009/2500 ━━━━━━━━━━━━━━━━━━━━ 55s 114ms/step - accuracy: 0.7507 - loss: 0.5136Batch 2010: accuracy=0.7518, loss=0.5142
# 2019/2500 ━━━━━━━━━━━━━━━━━━━━ 54s 114ms/step - accuracy: 0.7507 - loss: 0.5137Batch 2020: accuracy=0.7518, loss=0.5143
# 2029/2500 ━━━━━━━━━━━━━━━━━━━━ 53s 114ms/step - accuracy: 0.7507 - loss: 0.5137Batch 2030: accuracy=0.7517, loss=0.5143
# 2039/2500 ━━━━━━━━━━━━━━━━━━━━ 52s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2040: accuracy=0.7516, loss=0.5145
# 2049/2500 ━━━━━━━━━━━━━━━━━━━━ 51s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2050: accuracy=0.7517, loss=0.5143
# 2059/2500 ━━━━━━━━━━━━━━━━━━━━ 50s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2060: accuracy=0.7516, loss=0.5143
# 2069/2500 ━━━━━━━━━━━━━━━━━━━━ 48s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2070: accuracy=0.7516, loss=0.5145
# 2079/2500 ━━━━━━━━━━━━━━━━━━━━ 47s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2080: accuracy=0.7517, loss=0.5145
# 2089/2500 ━━━━━━━━━━━━━━━━━━━━ 46s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2090: accuracy=0.7514, loss=0.5145
# 2099/2500 ━━━━━━━━━━━━━━━━━━━━ 45s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2100: accuracy=0.7514, loss=0.5145
# 2109/2500 ━━━━━━━━━━━━━━━━━━━━ 44s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2110: accuracy=0.7513, loss=0.5145
# 2119/2500 ━━━━━━━━━━━━━━━━━━━━ 43s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2120: accuracy=0.7513, loss=0.5146
# 2129/2500 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2130: accuracy=0.7514, loss=0.5146
# 2139/2500 ━━━━━━━━━━━━━━━━━━━━ 41s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2140: accuracy=0.7514, loss=0.5145
# 2149/2500 ━━━━━━━━━━━━━━━━━━━━ 39s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2150: accuracy=0.7514, loss=0.5144
# 2159/2500 ━━━━━━━━━━━━━━━━━━━━ 38s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2160: accuracy=0.7512, loss=0.5147
# 2169/2500 ━━━━━━━━━━━━━━━━━━━━ 37s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2170: accuracy=0.7513, loss=0.5146
# 2179/2500 ━━━━━━━━━━━━━━━━━━━━ 36s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2180: accuracy=0.7513, loss=0.5146
# 2189/2500 ━━━━━━━━━━━━━━━━━━━━ 35s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2190: accuracy=0.7513, loss=0.5148
# 2199/2500 ━━━━━━━━━━━━━━━━━━━━ 34s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2200: accuracy=0.7514, loss=0.5148
# 2209/2500 ━━━━━━━━━━━━━━━━━━━━ 33s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2210: accuracy=0.7514, loss=0.5148
# 2219/2500 ━━━━━━━━━━━━━━━━━━━━ 31s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2220: accuracy=0.7515, loss=0.5148
# 2229/2500 ━━━━━━━━━━━━━━━━━━━━ 30s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2230: accuracy=0.7512, loss=0.5150
# 2239/2500 ━━━━━━━━━━━━━━━━━━━━ 29s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2240: accuracy=0.7514, loss=0.5149
# 2249/2500 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - accuracy: 0.7508 - loss: 0.5137Batch 2250: accuracy=0.7513, loss=0.5148
# 2259/2500 ━━━━━━━━━━━━━━━━━━━━ 27s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2260: accuracy=0.7511, loss=0.5151
# 2269/2500 ━━━━━━━━━━━━━━━━━━━━ 26s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2270: accuracy=0.7511, loss=0.5149
# 2279/2500 ━━━━━━━━━━━━━━━━━━━━ 25s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2280: accuracy=0.7510, loss=0.5151
# 2289/2500 ━━━━━━━━━━━━━━━━━━━━ 23s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2290: accuracy=0.7509, loss=0.5152
# 2299/2500 ━━━━━━━━━━━━━━━━━━━━ 22s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2300: accuracy=0.7509, loss=0.5151
# 2309/2500 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2310: accuracy=0.7508, loss=0.5154
# 2319/2500 ━━━━━━━━━━━━━━━━━━━━ 20s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2320: accuracy=0.7508, loss=0.5153
# 2329/2500 ━━━━━━━━━━━━━━━━━━━━ 19s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2330: accuracy=0.7508, loss=0.5151
# 2339/2500 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2340: accuracy=0.7508, loss=0.5151
# 2349/2500 ━━━━━━━━━━━━━━━━━━━━ 17s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2350: accuracy=0.7507, loss=0.5152
# 2359/2500 ━━━━━━━━━━━━━━━━━━━━ 16s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2360: accuracy=0.7508, loss=0.5151
# 2369/2500 ━━━━━━━━━━━━━━━━━━━━ 14s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2370: accuracy=0.7509, loss=0.5150
# 2379/2500 ━━━━━━━━━━━━━━━━━━━━ 13s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2380: accuracy=0.7508, loss=0.5150
# 2389/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2390: accuracy=0.7505, loss=0.5152
# 2399/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2400: accuracy=0.7507, loss=0.5150
# 2409/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2410: accuracy=0.7506, loss=0.5151
# 2419/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2420: accuracy=0.7506, loss=0.5150
# 2429/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.7508 - loss: 0.5138Batch 2430: accuracy=0.7506, loss=0.5150
# 2439/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.7508 - loss: 0.5139Batch 2440: accuracy=0.7506, loss=0.5150
# 2449/2500 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.7508 - loss: 0.5139Batch 2450: accuracy=0.7505, loss=0.5151
# 2459/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.7508 - loss: 0.5139Batch 2460: accuracy=0.7507, loss=0.5149
# 2469/2500 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.7508 - loss: 0.5139Batch 2470: accuracy=0.7508, loss=0.5147
# 2479/2500 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.7508 - loss: 0.5139Batch 2480: accuracy=0.7508, loss=0.5147
# 2489/2500 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.7508 - loss: 0.5139Batch 2490: accuracy=0.7507, loss=0.5149
# 2499/2500 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7508 - loss: 0.5139Batch 2500: accuracy=0.7507, loss=0.5148
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7508 - loss: 0.5139
# Epoch 10: val_loss did not improve from 0.47827
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 358s 143ms/step - accuracy: 0.7508 - loss: 0.5139 - val_accuracy: 0.7782 - val_loss: 0.4792 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 9.

# %%
#Fine tuuning model start 


# Unfreeze the base model
base_model.trainable = True

# Freeze the first 100 layers (optional, based on your use case)
for layer in base_model.layers[:100]:
    layer.trainable = False

# Recompile the model with a lower learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),  # Reduced learning rate
    loss='binary_crossentropy', 
    metrics=['accuracy']
)

# Fine-tuning training
fine_tune_epochs = 10  # Adjust based on experiment results

history_fine = model.fit(
    train_dataset,                    # Your training dataset
    validation_data=val_dataset,      # Your validation dataset
    epochs=fine_tune_epochs,          # Number of fine-tuning epochs
    callbacks=callbacks,              # Previously defined callbacks
    verbose=1                         # Displays training progress
)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    1562       with c_api_util.tf_buffer() as buf:   # pytype: disable=wrong-arg-count
# -> 1563         pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    1564         data = pywrap_tf_session.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'gradient_tape/functional_1/block12_sepconv3_1/separable_conv2d/DepthwiseConv2dNativeBackpropInput' has no attr named '_read_only_resource_inputs'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2c2ba736ed88> in <cell line: 21>()
#      19 fine_tune_epochs = 10  # Adjust based on experiment results
#      20
# ---> 21 history_fine = model.fit(
#      22     train_dataset,                    # Your training dataset
#      23     validation_data=val_dataset,      # Your validation dataset
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316                 for step, iterator in epoch_iterator.enumerate_epoch():
#     317                     callbacks.on_train_batch_begin(step)
# --> 318                     logs = self.train_function(iterator)
#     319                     logs = self._pythonify_logs(logs)
#     320                     callbacks.on_train_batch_end(step, logs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     887       # This is the first call of __call__, so we have to initialize.
#     888       initializers = []
# --> 889       self._initialize(args, kwds, add_initializers_to=initializers)
#     890     finally:
#     891       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     694     )
#     695     # Force the definition of the function for these arguments
# --> 696     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697         args, kwds, self._variable_creation_config
#     698     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     597         # the function a weak reference to itself to avoid a reference cycle.
#     598         with OptionalXlaContext(compile_with_xla):
# --> 599           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600         return out
#     601
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      39     """Calls a converted version of original_func."""
#      40     try:
# ---> 41       return api.converted_call(
#      42           original_func,
#      43           args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337   if is_autograph_artifact(f):
#     338     logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339     return _call_unconverted(f, args, kwargs, options)
#     340
#     341   # If this is a partial, unwrap it and redo all the checks.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#     644
#     645   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in one_step_on_iterator(iterator)
#     119             """Runs a single training step given a Dataset iterator."""
#     120             data = next(iterator)
# --> 121             outputs = self.distribute_strategy.run(
#     122                 one_step_on_data, args=(data,)
#     123             )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1671       fn = autograph.tf_convert(
#    1672           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1674
#    1675   def reduce(self, reduce_op, value, axis):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    3261       kwargs = {}
#    3262     with self._container_strategy().scope():
# -> 3263       return self._call_for_each_replica(fn, args, kwargs)
#    3264
#    3265   def _call_for_each_replica(self, fn, args, kwargs):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    4059   def _call_for_each_replica(self, fn, args, kwargs):
#    4060     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061       return fn(*args, **kwargs)
#    4062
#    4063   def _reduce_to(self, reduce_op, value, destinations, options):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     887       # This is the first call of __call__, so we have to initialize.
#     888       initializers = []
# --> 889       self._initialize(args, kwds, add_initializers_to=initializers)
#     890     finally:
#     891       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     694     )
#     695     # Force the definition of the function for these arguments
# --> 696     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697         args, kwds, self._variable_creation_config
#     698     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#     985     deps_control_manager = ops.NullContextmanager()
#     986
# --> 987   with func_graph.as_default(), deps_control_manager as deps_ctx:
#     988     current_scope = variable_scope.get_variable_scope()
#     989     default_use_resource = current_scope.use_resource
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/auto_control_deps.py in __exit__(self, unused_type, unused_value, unused_traceback)
#     457       # Check for any resource inputs. If we find any, we update control_inputs
#     458       # and last_write_to_resource.
# --> 459       for inp, resource_type in _get_resource_inputs(op):
#     460         is_read = resource_type == ResourceType.READ_ONLY
#     461         input_id = ops.tensor_id(inp)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/auto_control_deps.py in _get_resource_inputs(op)
#     606 def _get_resource_inputs(op):
#     607   """Returns an iterable of resources touched by this `op`."""
# --> 608   reads, writes = utils.get_read_write_resource_inputs(op)
#     609   saturated = False
#     610   while not saturated:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/auto_control_deps_utils.py in get_read_write_resource_inputs(op)
#     103
#     104   try:
# --> 105     read_only_input_indices = op.get_attr(READ_ONLY_RESOURCE_INPUTS_ATTR)
#     106   except ValueError:
#     107     # Attr was not set. Add all resource inputs to `writes` and return.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    1561     try:
#    1562       with c_api_util.tf_buffer() as buf:   # pytype: disable=wrong-arg-count
# -> 1563         pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    1564         data = pywrap_tf_session.TF_GetBuffer(buf)
#    1565     except errors.InvalidArgumentError as e:
#
# KeyboardInterrupt:

# %%
# Save the final trained model
final_model_path = '/kaggle/working/Xception_model.h5'
model.save(final_model_path)
print(f"Final model saved as {final_model_path}.")
# Out:
# Final model saved as /kaggle/working/Xception_model.h5.

# %%
from tensorflow.keras.models import load_model
model = load_model(final_model_path)
print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %%
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels=None,                     # Test data may not have labels
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False                    # Keep test data in order for evaluation
)
# Out:
# Found 500 files.

# %%
test_file_paths = test_dataset.file_paths  # Use file_paths to get the paths of the test images

# Predict on the test dataset
predictions = model.predict(test_dataset)
predicted_classes = (predictions > 0.5).astype(int).flatten()  # Convert probabilities to binary classes

# Create a DataFrame for the predictions
output_df = pd.DataFrame({
    'ID': [os.path.basename(f) for f in test_file_paths],  # Extract filenames only
    'ImageType': predicted_classes  # Predictions (0 or 1)
})

# Save the predictions to a CSV file
output_csv_path = '/kaggle/working/test_predictions.csv'
output_df.to_csv(output_csv_path, index=False)
print(f"Predictions saved to {output_csv_path}.")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 569ms/step
# Predictions saved to /kaggle/working/test_predictions.csv.
